# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import re

def parse_standard_listing(item):

    try:
        title_element = item.find('p', class_='content__list--item--title')
        if not title_element or not title_element.find('a'):
            return None 

        detail_link = "贝壳租房网站" + title_element.find('a')['href']
        # 放弃品牌公寓类型数据的爬取
        if '/apartment/' in detail_link:
            return None

        listing_data = {
            '标题': 'N/A', '价格(元/月)': 0, '区域': 'N/A',
            '户型': 'N/A', '面积(㎡)': 'N/A', '朝向': 'N/A', '详情链接': 'N/A'
        }
        listing_data['标题'] = title_element.get_text(strip=True)
        listing_data['详情链接'] = detail_link

        price_element = item.find('span', class_='content__list--item-price')
        if price_element and price_element.find('em'):
            price_text = price_element.find('em').get_text(strip=True)
            listing_data['价格(元/月)'] = int(price_text) if price_text.isdigit() else 0
        else:
            return None 

        des_element = item.find('p', class_='content__list--item--des')
        if des_element:
            full_des_text = des_element.get_text(strip=True)
            des_parts = [part.strip() for part in full_des_text.split('/')]
            
            if des_parts:
                location_info = des_parts.pop(0).replace('·', ' - ')
                listing_data['区域'] = location_info

            for part in des_parts:
                if '㎡' in part:
                    listing_data['面积(㎡)'] = re.sub(r'\s*㎡', '', part)
                elif '室' in part or '厅' in part or '卫' in part:
                    listing_data['户型'] = part
                elif len(part) <= 2 and any(d in part for d in ['东', '南', '西', '北']):
                    listing_data['朝向'] = part
        
        return listing_data

    except Exception:
        return None

def get_beike_rent_info_final_v2(max_pages=5):
    base_url = "贝壳租房网站"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    }
    
    all_listings = []
    print(f"--- 自动跳过所有品牌公寓房源 ---")

    for page in range(1, max_pages + 1):
        url = f"{base_url}pg{page}/"
        print(f"正在爬取第 {page} 页: {url}")

        try:
            response = requests.get(url, headers=headers, timeout=15)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'lxml')
            
            listings_on_page = soup.find_all('div', class_='content__list--item')
            if not listings_on_page:
                print(f"警告: 在第 {page} 页没有找到房源信息，爬取提前结束。")
                break

            count_on_page = 0
            for item in listings_on_page:
                listing_data = parse_standard_listing(item)
                if listing_data:
                    all_listings.append(listing_data)
                    count_on_page += 1
            
            print(f"第 {page} 页成功解析 {count_on_page} 条【普通房源】。")

            sleep_time = random.uniform(2, 4)
            print(f"休眠 {sleep_time:.2f} 秒...")
            time.sleep(sleep_time)

        except requests.exceptions.RequestException as e:
            print(f"请求第 {page} 页时发生网络错误: {e}")
            break
            
    print("--- 爬取结束 ---")
    
    if all_listings:
        return pd.DataFrame(all_listings)
    else:
        return pd.DataFrame()

if __name__ == '__main__':
    PAGES_TO_SCRAPE = 20 #可以把数字改成自己想爬取的页数

    rent_data_df = get_beike_rent_info_final_v2(max_pages=PAGES_TO_SCRAPE)

    if not rent_data_df.empty:
        try:
            output_filename = '文件保存位置'
            columns_order = ['标题', '价格(元/月)', '区域', '户型', '面积(㎡)', '朝向', '详情链接']
            rent_data_df = rent_data_df.reindex(columns=columns_order) 
            
            rent_data_df.to_csv(output_filename, index=False, encoding='utf-8-sig')
            
            print(f"\n成功爬取 {len(rent_data_df)} 条【普通房源】信息。")
            print(f"数据已保存到文件: {output_filename}")
            print("\n数据预览:")
            print(rent_data_df.head())
        except Exception as e:
            print(f"保存文件时出错: {e}")
    else:
        print("\n未能爬取到任何有效的普通房源信息，程序结束。")
# Out:
# --- 【再次修正版】开始爬取，将自动跳过所有“品牌公寓”房源 ---
# 正在爬取第 1 页: https://nn.zu.ke.com/zufang/pg1/
# 第 1 页成功解析 17 条【普通房源】。
# 休眠 2.29 秒...
# 正在爬取第 2 页: https://nn.zu.ke.com/zufang/pg2/
# 第 2 页成功解析 17 条【普通房源】。
# 休眠 3.81 秒...
# 正在爬取第 3 页: https://nn.zu.ke.com/zufang/pg3/
# 第 3 页成功解析 17 条【普通房源】。
# 休眠 3.52 秒...
# 正在爬取第 4 页: https://nn.zu.ke.com/zufang/pg4/
# 第 4 页成功解析 18 条【普通房源】。
# 休眠 3.80 秒...
# 正在爬取第 5 页: https://nn.zu.ke.com/zufang/pg5/
# 第 5 页成功解析 30 条【普通房源】。
# 休眠 2.58 秒...
# 正在爬取第 6 页: https://nn.zu.ke.com/zufang/pg6/
# 第 6 页成功解析 30 条【普通房源】。
# 休眠 2.59 秒...
# 正在爬取第 7 页: https://nn.zu.ke.com/zufang/pg7/
# 第 7 页成功解析 22 条【普通房源】。
# 休眠 2.53 秒...
# 正在爬取第 8 页: https://nn.zu.ke.com/zufang/pg8/
# 第 8 页成功解析 22 条【普通房源】。
# 休眠 2.80 秒...
# 正在爬取第 9 页: https://nn.zu.ke.com/zufang/pg9/
# 第 9 页成功解析 23 条【普通房源】。
# 休眠 3.03 秒...
# 正在爬取第 10 页: https://nn.zu.ke.com/zufang/pg10/
# 第 10 页成功解析 22 条【普通房源】。
# 休眠 2.72 秒...
# 正在爬取第 11 页: https://nn.zu.ke.com/zufang/pg11/
# 第 11 页成功解析 18 条【普通房源】。
# 休眠 2.11 秒...
# 正在爬取第 12 页: https://nn.zu.ke.com/zufang/pg12/
# 第 12 页成功解析 18 条【普通房源】。
# 休眠 3.26 秒...
# 正在爬取第 13 页: https://nn.zu.ke.com/zufang/pg13/
# 第 13 页成功解析 18 条【普通房源】。
# 休眠 3.20 秒...
# 正在爬取第 14 页: https://nn.zu.ke.com/zufang/pg14/
# 第 14 页成功解析 19 条【普通房源】。
# 休眠 2.59 秒...
# 正在爬取第 15 页: https://nn.zu.ke.com/zufang/pg15/
# 第 15 页成功解析 21 条【普通房源】。
# 休眠 3.24 秒...
# 正在爬取第 16 页: https://nn.zu.ke.com/zufang/pg16/
# 第 16 页成功解析 25 条【普通房源】。
# 休眠 2.07 秒...
# 正在爬取第 17 页: https://nn.zu.ke.com/zufang/pg17/
# 第 17 页成功解析 16 条【普通房源】。
# 休眠 2.24 秒...
# 正在爬取第 18 页: https://nn.zu.ke.com/zufang/pg18/
# 第 18 页成功解析 22 条【普通房源】。
# 休眠 3.74 秒...
# 正在爬取第 19 页: https://nn.zu.ke.com/zufang/pg19/
# 第 19 页成功解析 20 条【普通房源】。
# 休眠 3.58 秒...
# 正在爬取第 20 页: https://nn.zu.ke.com/zufang/pg20/
# 第 20 页成功解析 19 条【普通房源】。
# 休眠 3.48 秒...
# --- 爬取结束 ---
#
# 成功爬取 414 条【普通房源】信息。
# 数据已保存到文件: E:\xiangmu\zufang\beike_rent_nn.csv
#
# 数据预览:
#                              标题  价格(元/月)                         区域      户型  \
# 0                整租·骋望珺玺 3室2厅 南     1800               江南区-五一路-骋望珺玺  3室2厅2卫
# 1              整租·中海哈罗学府 3室2厅 南     1800              邕宁区-龙岗-中海哈罗学府  3室2厅2卫
# 2  整租·广西壮族自治区疾病预防控制中心宿舍区 4室2厅 南     2200  青秀区-星湖-广西壮族自治区疾病预防控制中心宿舍区  4室2厅2卫
# 3                 整租·龙滩苑 3室2厅 南     4500              青秀区-东盟商务区-龙滩苑  3室2厅2卫
# 4               整租·君华•锦云 4室2厅 北     2500               邕宁区-龙岗-君华•锦云  4室2厅2卫
#
#     面积(㎡) 朝向                                               详情链接
# 0   84.00  南  https://nn.zu.ke.com/zufang/NN2061010309283315...
# 1   97.00  南  https://nn.zu.ke.com/zufang/NN2042458285893746...
# 2  123.50  南  https://nn.zu.ke.com/zufang/NN2002335869402349...
# 3  141.00  南  https://nn.zu.ke.com/zufang/NN2036798560841760...
# 4  125.00  北  https://nn.zu.ke.com/zufang/NN2041844326283083...

# %%
import pandas as pd
import requests
import time
import random


GAODE_API_KEY = "你的api" 


COMPANY_ADDRESS = "公司地址" 

INPUT_CSV = '读取的文件'
OUTPUT_CSV = '输出的文件' 


def get_coordinates(address, api_key):
    geocode_url = "https://restapi.amap.com/v3/geocode/geo"
    params = {'key': api_key, 'address': address, 'city': '你爬取的城市'}
    try:
        response = requests.get(geocode_url, params=params, timeout=10)
        data = response.json()
        if data['status'] == '1' and data['geocodes']:
            return data['geocodes'][0]['location']
    except Exception as e:
        print(f"  地址解析API请求失败: {e}")
    return None

def get_drive_info(origin, destination, api_key):
    url = "https://restapi.amap.com/v3/direction/driving"
    params = {'key': api_key, 'origin': origin, 'destination': destination}
    try:
        response = requests.get(url, params=params, timeout=10)
        data = response.json()
        if data['status'] == '1' and data.get('route', {}).get('paths'):
            path = data['route']['paths'][0]
            distance_km = round(int(path['distance']) / 1000, 1)
            duration_min = round(int(path['duration']) / 60)
            return f"{distance_km}公里", f"{duration_min}分钟"
    except Exception:
        pass
    return "计算失败", "计算失败"

def get_transit_info(origin, destination, api_key):
    url = "https://restapi.amap.com/v3/direction/transit/integrated"
    params = {
        'key': api_key,
        'origin': origin,
        'destination': destination,
        'city': '你所爬取的城市', 
        'strategy': '0' 
    }
    try:
        response = requests.get(url, params=params, timeout=10)
        data = response.json()
        if data['status'] == '1' and data.get('route', {}).get('transits'):
            transit = data['route']['transits'][0]
            duration_min = round(int(transit['duration']) / 60)
            return f"{duration_min}分钟"
    except Exception:
        pass
    return "计算失败"

def get_walking_info(origin, destination, api_key):
    url = "https://restapi.amap.com/v3/direction/walking"
    params = {'key': api_key, 'origin': origin, 'destination': destination}
    try:
        response = requests.get(url, params=params, timeout=10)
        data = response.json()
        if data['status'] == '1' and data.get('route', {}).get('paths'):
            path = data['route']['paths'][0]
            distance_km = round(int(path['distance']) / 1000, 1)
            duration_min = round(int(path['duration']) / 60)
            return f"{distance_km}公里", f"{duration_min}分钟"
    except Exception:
        pass
    return "计算失败", "计算失败"

def main():
    if GAODE_API_KEY == "在这里粘贴你从高德开放平台获取的Key":
        print("错误：请先在代码中配置你的高德API Key！")
        return

    try:
        df = pd.read_csv(INPUT_CSV)
        print(f"成功读取 {len(df)} 条房源数据自 '{INPUT_CSV}'。")
    except FileNotFoundError:
        print(f"错误：找不到输入文件 '{INPUT_CSV}'。")
        return

    print(f"正在获取公司地址 '{COMPANY_ADDRESS}' 的坐标...")
    company_coords = get_coordinates(COMPANY_ADDRESS, GAODE_API_KEY)
    if not company_coords:
        print("无法获取公司坐标，程序终止。")
        return
    print(f"公司坐标获取成功: {company_coords}")

    new_columns_data = []
    total = len(df)
    for index, row in df.iterrows():
        rent_address = f"你所爬取的城市{row['区域'].replace(' - ', '')}"
        print(f"\n({index + 1}/{total}) 正在处理: {row['标题']}")
        
        commute_info = {
            '驾车距离': '获取坐标失败', '驾车时间': '获取坐标失败',
            '公交时间': '获取坐标失败', '步行距离': '获取坐标失败', '步行时间': '获取坐标失败'
        }

        rent_coords = get_coordinates(rent_address, GAODE_API_KEY)
        
        if rent_coords:
            drive_dist, drive_time = get_drive_info(rent_coords, company_coords, GAODE_API_KEY)
            commute_info['驾车距离'] = drive_dist
            commute_info['驾车时间'] = drive_time
            print(f"  驾车: {drive_dist}, {drive_time}")

            transit_time = get_transit_info(rent_coords, company_coords, GAODE_API_KEY)
            commute_info['公交时间'] = transit_time
            print(f"  公交: {transit_time}")

            walk_dist, walk_time = get_walking_info(rent_coords, company_coords, GAODE_API_KEY)
            commute_info['步行距离'] = walk_dist
            commute_info['步行时间'] = walk_time
            print(f"  步行: {walk_dist}, {walk_time}")
        
        new_columns_data.append(commute_info)

        time.sleep(random.uniform(0.1, 0.3)) #控制频率

    commute_df = pd.DataFrame(new_columns_data, index=df.index)
    df_final = pd.concat([df, commute_df], axis=1)

    try:
        df_final.to_csv(OUTPUT_CSV, index=False, encoding='utf-8-sig')
        print(f"\n--- 处理完成！---")
        print(f"已将包含多种出行方式的结果保存到新文件: '{OUTPUT_CSV}'")
        print("\n最终数据预览:")
        preview_cols = ['标题', '价格(元/月)', '驾车时间', '公交时间', '步行时间']
        print(df_final[preview_cols].head())
    except Exception as e:
        print(f"保存文件时出错: {e}")

if __name__ == '__main__':
    main()
# Out:
# 成功读取 414 条房源数据自 'E:\xiangmu\zufang\beike_rent_nn.csv'。
# 正在获取公司地址 '南宁市兴宁区朝阳路38号' 的坐标...
# 公司坐标获取成功: 108.321461,22.816342
#
# (1/414) 正在处理: 整租·骋望珺玺 3室2厅 南
#   驾车: 9.7公里, 21分钟
#   公交: 50分钟
#   步行: 8.4公里, 112分钟
#
# (2/414) 正在处理: 整租·中海哈罗学府 3室2厅 南
#   驾车: 19.9公里, 44分钟
#   公交: 76分钟
#   步行: 19.4公里, 258分钟
#
# (3/414) 正在处理: 整租·广西壮族自治区疾病预防控制中心宿舍区 4室2厅 南
#   驾车: 3.6公里, 12分钟
#   公交: 34分钟
#   步行: 3.0公里, 40分钟
#
# (4/414) 正在处理: 整租·龙滩苑 3室2厅 南
#   驾车: 8.1公里, 33分钟
#   公交: 24分钟
#   步行: 7.6公里, 102分钟
#
# (5/414) 正在处理: 整租·君华•锦云 4室2厅 北
#   驾车: 18.3公里, 47分钟
#   公交: 67分钟
#   步行: 18.1公里, 241分钟
#
# (6/414) 正在处理: 整租·大唐盛世观湖 4室2厅 南
#   驾车: 20.4公里, 44分钟
#   公交: 87分钟
#   步行: 19.8公里, 264分钟
#
# (7/414) 正在处理: 整租·永凯春晖花园西C区 3室2厅 南
#   驾车: 8.1公里, 35分钟
#   公交: 30分钟
#   步行: 8.0公里, 107分钟
#
# (8/414) 正在处理: 整租·五象澜庭府锦苑 3室2厅 东南/南
#   驾车: 15.3公里, 43分钟
#   公交: 46分钟
#   步行: 14.6公里, 194分钟
#
# (9/414) 正在处理: 整租·恒悦居 3室2厅 南/北
#   驾车: 21.1公里, 49分钟
#   公交: 60分钟
#   步行: 14.6公里, 195分钟
#
# (10/414) 正在处理: 整租·万科紫台 4室3厅 南
#   驾车: 11.7公里, 40分钟
#   公交: 45分钟
#   步行: 10.8公里, 145分钟
#
# (11/414) 正在处理: 整租·宏桂东盛 3室2厅 南
#   驾车: 11.1公里, 39分钟
#   公交: 50分钟
#   步行: 10.6公里, 141分钟
#
# (12/414) 正在处理: 整租·龙光世纪中心 3室1厅 南
#   驾车: 8.7公里, 41分钟
#   公交: 27分钟
#   步行: 8.7公里, 116分钟
#
# (13/414) 正在处理: 整租·南宁市南湖公务员住宅小区 4室2厅 南
#   驾车: 5.7公里, 25分钟
#   公交: 28分钟
#   步行: 5.6公里, 75分钟
#
# (14/414) 正在处理: 整租·东长小区 3室2厅 东南
#   驾车: 4.6公里, 20分钟
#   公交: 28分钟
#   步行: 4.5公里, 60分钟
#
# (15/414) 正在处理: 整租·君华•锦云 4室2厅 东南
#   驾车: 18.3公里, 48分钟
#   公交: 67分钟
#   步行: 18.1公里, 241分钟
#
# (16/414) 正在处理: 整租·广西区糖业供销公司宿舍 3室2厅 东南
#   驾车: 6.0公里, 31分钟
#   公交: 23分钟
#   步行: 6.2公里, 83分钟
#
# (17/414) 正在处理: 整租·万科金域中央一期 3室2厅 南
#   驾车: 11.2公里, 39分钟
#   公交: 45分钟
#   步行: 10.7公里, 143分钟
#
# (18/414) 正在处理: 整租·恒大悦龙台 3室2厅 南
#   驾车: 15.9公里, 39分钟
#   公交: 73分钟
#   步行: 16.1公里, 215分钟
#
# (19/414) 正在处理: 整租·和美春天 4室2厅 南
#   驾车: 11.5公里, 36分钟
#   公交: 42分钟
#   步行: 11.3公里, 150分钟
#
# (20/414) 正在处理: 整租·万科公望 4室2厅 南
#   驾车: 20.9公里, 44分钟
#   公交: 93分钟
#   步行: 18.7公里, 250分钟
#
# (21/414) 正在处理: 整租·龙光世纪中心 4室1厅 南
#   驾车: 8.7公里, 41分钟
#   公交: 27分钟
#   步行: 8.7公里, 116分钟
#
# (22/414) 正在处理: 整租·印象·愉景湾 4室2厅 东南
#   驾车: 20.9公里, 49分钟
#   公交: 79分钟
#   步行: 19.6公里, 261分钟
#
# (23/414) 正在处理: 整租·万科金域中央一期 3室2厅 南
#   驾车: 11.2公里, 40分钟
#   公交: 45分钟
#   步行: 10.7公里, 143分钟
#
# (24/414) 正在处理: 整租·盘龙居小区 3室2厅 南/北
#   驾车: 8.6公里, 32分钟
#   公交: 46分钟
#   步行: 7.7公里, 103分钟
#
# (25/414) 正在处理: 整租·凤岭名园 4室2厅 北
#   驾车: 14.6公里, 37分钟
#   公交: 50分钟
#   步行: 11.0公里, 147分钟
#
# (26/414) 正在处理: 整租·霖峰壹號2组团 3室2厅 东南
#   驾车: 12.5公里, 34分钟
#   公交: 44分钟
#   步行: 8.5公里, 113分钟
#
# (27/414) 正在处理: 整租·五象澜庭府锦苑 3室2厅 南/北
#   驾车: 15.3公里, 44分钟
#   公交: 46分钟
#   步行: 14.6公里, 194分钟
#
# (28/414) 正在处理: 整租·联发·尚品 3室2厅 南
#   驾车: 14.4公里, 44分钟
#   公交: 60分钟
#   步行: 14.1公里, 188分钟
#
# (29/414) 正在处理: 整租·龙光·君御华府 2室1厅 南
#   驾车: 7.7公里, 33分钟
#   公交: 38分钟
#   步行: 7.1公里, 95分钟
#
# (30/414) 正在处理: 整租·港保苑 2室2厅 西
#   驾车: 12.4公里, 37分钟
#   公交: 44分钟
#   步行: 11.6公里, 155分钟
#
# (31/414) 正在处理: 整租·金科博翠山 3室2厅 南
#   驾车: 13.4公里, 39分钟
#   公交: 48分钟
#   步行: 13.0公里, 174分钟
#
# (32/414) 正在处理: 整租·大唐盛世观湖 4室2厅 南
#   驾车: 20.4公里, 45分钟
#   公交: 87分钟
#   步行: 19.8公里, 264分钟
#
# (33/414) 正在处理: 整租·华润二十四城 3室2厅 南
#   驾车: 15.3公里, 44分钟
#   公交: 45分钟
#   步行: 14.4公里, 192分钟
#
# (34/414) 正在处理: 整租·华龙苑小区 3室2厅 南
#   驾车: 6.4公里, 26分钟
#   公交: 38分钟
#   步行: 5.3公里, 71分钟
#
# (35/414) 正在处理: 整租·荣和大地二组团 6室0厅 东南
#   驾车: 10.8公里, 34分钟
#   公交: 48分钟
#   步行: 9.5公里, 127分钟
#
# (36/414) 正在处理: 整租·华龙苑小区 3室2厅 南
#   驾车: 6.4公里, 26分钟
#   公交: 38分钟
#   步行: 5.3公里, 71分钟
#
# (37/414) 正在处理: 整租·金科博翠山 3室2厅 南
#   驾车: 13.4公里, 39分钟
#   公交: 48分钟
#   步行: 13.0公里, 174分钟
#
# (38/414) 正在处理: 整租·中房翡翠园二期 3室2厅 南
#   驾车: 10.5公里, 34分钟
#   公交: 35分钟
#   步行: 10.4公里, 138分钟
#
# (39/414) 正在处理: 整租·虹桥新城 1室1厅 南
#   驾车: 13.4公里, 36分钟
#   公交: 45分钟
#   步行: 9.3公里, 124分钟
#
# (40/414) 正在处理: 整租·印象·愉景湾 4室2厅 南
#   驾车: 20.9公里, 49分钟
#   公交: 79分钟
#   步行: 19.6公里, 261分钟
#
# (41/414) 正在处理: 整租·威宁青运村 3室2厅 东南
#   驾车: 12.3公里, 41分钟
#   公交: 51分钟
#   步行: 12.0公里, 161分钟
#
# (42/414) 正在处理: 整租·保利·童心缘 1室1厅 南
#   驾车: 13.9公里, 37分钟
#   公交: 54分钟
#   步行: 10.3公里, 137分钟
#
# (43/414) 正在处理: 整租·星湖路北二里8号小区 4室2厅 南/北
#   驾车: 3.8公里, 17分钟
#   公交: 18分钟
#   步行: 2.8公里, 37分钟
#
# (44/414) 正在处理: 整租·恒大绿洲3期 2室2厅 南
#   驾车: 8.8公里, 30分钟
#   公交: 42分钟
#   步行: 8.3公里, 110分钟
#
# (45/414) 正在处理: 整租·建发五象印月 4室2厅 南/北
#   驾车: 14.4公里, 43分钟
#   公交: 52分钟
#   步行: 12.2公里, 162分钟
#
# (46/414) 正在处理: 整租·城市碧园 4室2厅 东南
#   驾车: 7.9公里, 25分钟
#   公交: 18分钟
#   步行: 4.7公里, 62分钟
#
# (47/414) 正在处理: 整租·云星钱隆首府E地块 3室2厅 南
#   驾车: 9.8公里, 37分钟
#   公交: 40分钟
#   步行: 9.3公里, 124分钟
#
# (48/414) 正在处理: 整租·万科星都荟三期 4室2厅 南/北
#   驾车: 17.0公里, 45分钟
#   公交: 72分钟
#   步行: 14.9公里, 199分钟
#
# (49/414) 正在处理: 整租·保利明玥江山 3室2厅 南
#   驾车: 14.9公里, 45分钟
#   公交: 54分钟
#   步行: 14.5公里, 193分钟
#
# (50/414) 正在处理: 整租·融创九棠府二期 4室2厅 南
#   驾车: 15.1公里, 44分钟
#   公交: 62分钟
#   步行: 14.2公里, 189分钟
#
# (51/414) 正在处理: 整租·荣和·千千树 3室1厅 南/北
#   驾车: 12.4公里, 34分钟
#   公交: 48分钟
#   步行: 8.7公里, 116分钟
#
# (52/414) 正在处理: 整租·宝能五象湖一号 3室2厅 南
#   驾车: 13.2公里, 42分钟
#   公交: 49分钟
#   步行: 11.8公里, 158分钟
#
# (53/414) 正在处理: 整租·融创九棠府二期 4室2厅 南
#   驾车: 15.1公里, 44分钟
#   公交: 62分钟
#   步行: 14.2公里, 189分钟
#
# (54/414) 正在处理: 整租·云星钱隆首府E地块 3室2厅 南
#   驾车: 9.8公里, 37分钟
#   公交: 40分钟
#   步行: 9.3公里, 124分钟
#
# (55/414) 正在处理: 整租·万科星都荟三期 4室2厅 南/北
#   驾车: 17.0公里, 45分钟
#   公交: 72分钟
#   步行: 14.9公里, 199分钟
#
# (56/414) 正在处理: 整租·阳光100上东国际 1室0厅 南
#   驾车: 9.9公里, 33分钟
#   公交: 29分钟
#   步行: 9.4公里, 126分钟
#
# (57/414) 正在处理: 整租·保利明玥江山 3室2厅 南
#   驾车: 14.9公里, 45分钟
#   公交: 54分钟
#   步行: 14.5公里, 193分钟
#
# (58/414) 正在处理: 整租·柏涛湾小区 3室2厅 复式 南
#   驾车: 5.1公里, 25分钟
#   公交: 34分钟
#   步行: 4.7公里, 62分钟
#
# (59/414) 正在处理: 整租·驰程天拓 2室1厅 西
#   驾车: 16.7公里, 34分钟
#   公交: 30分钟
#   步行: 14.0公里, 186分钟
#
# (60/414) 正在处理: 整租·空军集资楼小区 4室2厅 南/北
#   驾车: 4.1公里, 17分钟
#   公交: 25分钟
#   步行: 2.8公里, 37分钟
#
# (61/414) 正在处理: 整租·云星时代广场 1室1厅 东南
#   驾车: 11.3公里, 40分钟
#   公交: 44分钟
#   步行: 10.0公里, 134分钟
#
# (62/414) 正在处理: 整租·中房翡翠园二期 3室2厅 南
#   驾车: 10.5公里, 34分钟
#   公交: 35分钟
#   步行: 10.4公里, 138分钟
#
# (63/414) 正在处理: 整租·金科博翠山 3室2厅 南/北
#   驾车: 13.4公里, 39分钟
#   公交: 48分钟
#   步行: 13.0公里, 174分钟
#
# (64/414) 正在处理: 整租·合景天汇广场 4室2厅 南/北
#   驾车: 15.0公里, 44分钟
#   公交: 40分钟
#   步行: 13.8公里, 185分钟
#
# (65/414) 正在处理: 整租·金都新巢时代 1室1厅 南
#   驾车: 2.3公里, 11分钟
#   公交: 28分钟
#   步行: 2.0公里, 26分钟
#
# (66/414) 正在处理: 整租·平安家园 3室2厅 南/北
#   驾车: 7.5公里, 32分钟
#   公交: 31分钟
#   步行: 7.6公里, 102分钟
#
# (67/414) 正在处理: 整租·中铁江湾山语城 4室2厅 南
#   驾车: 18.8公里, 40分钟
#   公交: 76分钟
#   步行: 17.3公里, 231分钟
#
# (68/414) 正在处理: 整租·保利领秀前城领秀府 4室2厅 南
#   驾车: 14.7公里, 44分钟
#   公交: 57分钟
#   步行: 13.0公里, 173分钟
#
# (69/414) 正在处理: 整租·云星城 1室1厅 南
#   驾车: 2.1公里, 10分钟
#   公交: 11分钟
#   步行: 2.0公里, 27分钟
#
# (70/414) 正在处理: 整租·华银阁 2室1厅 南
#   驾车: 2.0公里, 7分钟
#   公交: 12分钟
#   步行: 1.6公里, 21分钟
#
# (71/414) 正在处理: 整租·嘉和自由空间 1室0厅 南
#   驾车: 2.3公里, 9分钟
#   公交: 18分钟
#   步行: 1.5公里, 20分钟
#
# (72/414) 正在处理: 整租·广西民族宫 2室1厅 东
#   驾车: 1.7公里, 7分钟
#   公交: 11分钟
#   步行: 1.6公里, 22分钟
#
# (73/414) 正在处理: 整租·亚航财富中心 1室1厅 北
#   驾车: 5.3公里, 25分钟
#   公交: 22分钟
#   步行: 5.4公里, 72分钟
#
# (74/414) 正在处理: 整租·印象·愉景湾 3室2厅 南
#   驾车: 20.9公里, 48分钟
#   公交: 79分钟
#   步行: 19.6公里, 261分钟
#
# (75/414) 正在处理: 整租·亚航财富中心 1室1厅 北
#   驾车: 5.3公里, 25分钟
#   公交: 22分钟
#   步行: 5.4公里, 72分钟
#
# (76/414) 正在处理: 整租·农行宿舍 3室2厅 南
#   驾车: 4.1公里, 17分钟
#   公交: 25分钟
#   步行: 2.8公里, 37分钟
#
# (77/414) 正在处理: 整租·利海亚洲国际 1室1厅 南
#   驾车: 8.7公里, 44分钟
#   公交: 31分钟
#   步行: 8.6公里, 114分钟
#
# (78/414) 正在处理: 整租·大唐盛世观湖 4室2厅 南/北
#   驾车: 20.4公里, 45分钟
#   公交: 87分钟
#   步行: 19.8公里, 264分钟
#
# (79/414) 正在处理: 整租·广西民族宫 1室1厅 东南
#   驾车: 1.7公里, 7分钟
#   公交: 11分钟
#   步行: 1.6公里, 22分钟
#
# (80/414) 正在处理: 整租·融创九棠府二期 4室2厅 南
#   驾车: 15.1公里, 44分钟
#   公交: 62分钟
#   步行: 14.2公里, 189分钟
#
# (81/414) 正在处理: 整租·广西路桥总公司一分公司五一路生活区 3室1厅 南
#   驾车: 7.5公里, 19分钟
#   公交: 30分钟
#   步行: 6.0公里, 80分钟
#
# (82/414) 正在处理: 整租·中铁交通天地明珠 4室2厅 南
#   驾车: 18.3公里, 46分钟
#   公交: 67分钟
#   步行: 18.1公里, 241分钟
#
# (83/414) 正在处理: 整租·荣和山水美地4组团微笑湾 3室2厅 南/北
#   驾车: 9.3公里, 33分钟
#   公交: 37分钟
#   步行: 9.3公里, 124分钟
#
# (84/414) 正在处理: 整租·星湖路南一里14 3室2厅 南/北
#   驾车: 2.0公里, 10分钟
#   公交: 16分钟
#   步行: 1.5公里, 20分钟
#
# (85/414) 正在处理: 整租·盛邦珑湖 6室2厅 南
#   驾车: 12.7公里, 37分钟
#   公交: 63分钟
#   步行: 12.0公里, 160分钟
#
# (86/414) 正在处理: 整租·万达茂·御江国际 3室2厅 南
#   驾车: 15.2公里, 35分钟
#   公交: 89分钟
#   步行: 15.2公里, 203分钟
#
# (87/414) 正在处理: 整租·长湖景苑 5室2厅 东南/南
#   驾车: 5.0公里, 23分钟
#   公交: 33分钟
#   步行: 4.9公里, 66分钟
#
# (88/414) 正在处理: 整租·中房翡翠园二期 4室2厅 南
#   驾车: 10.5公里, 34分钟
#   公交: 35分钟
#   步行: 10.4公里, 138分钟
#
# (89/414) 正在处理: 整租·凯丰大厦 1室0厅 东
#   驾车: 2.6公里, 13分钟
#   公交: 24分钟
#   步行: 2.2公里, 30分钟
#
# (90/414) 正在处理: 整租·香格里拉花园 5室2厅 东南
#   驾车: 7.5公里, 32分钟
#   公交: 38分钟
#   步行: 7.0公里, 94分钟
#
# (91/414) 正在处理: 整租·外滩新城 5室2厅 南/北
#   驾车: 1.4公里, 7分钟
#   公交: 18分钟
#   步行: 1.4公里, 18分钟
#
# (92/414) 正在处理: 整租·融创九棠府一期 4室2厅 东南
#   驾车: 14.4公里, 41分钟
#   公交: 58分钟
#   步行: 14.1公里, 188分钟
#
# (93/414) 正在处理: 整租·汇金苑 2室1厅 东南
#   驾车: 5.2公里, 23分钟
#   公交: 22分钟
#   步行: 5.1公里, 67分钟
#
# (94/414) 正在处理: 合租·江悦蓝湾 4居室 东南卧
#   驾车: 9.3公里, 32分钟
#   公交: 40分钟
#   步行: 9.4公里, 125分钟
#
# (95/414) 正在处理: 整租·天誉城 3室2厅 南
#   驾车: 15.6公里, 44分钟
#   公交: 50分钟
#   步行: 14.9公里, 198分钟
#
# (96/414) 正在处理: 整租·阳光绿城第六组团 3室2厅 东/南
#   驾车: 6.1公里, 23分钟
#   公交: 39分钟
#   步行: 5.4公里, 72分钟
#
# (97/414) 正在处理: 整租·中海半山壹号 5室2厅 南
#   驾车: 20.6公里, 49分钟
#   公交: 85分钟
#   步行: 19.0公里, 254分钟
#
# (98/414) 正在处理: 整租·盘龙居小区 4室2厅 东南
#   驾车: 8.6公里, 31分钟
#   公交: 46分钟
#   步行: 7.7公里, 103分钟
#
# (99/414) 正在处理: 整租·东长小区 4室2厅 南/北
#   驾车: 4.6公里, 20分钟
#   公交: 28分钟
#   步行: 4.5公里, 60分钟
#
# (100/414) 正在处理: 整租·水泥厂宿舍 3室2厅 南/北
#   驾车: 21.3公里, 48分钟
#   公交: 69分钟
#   步行: 20.0公里, 266分钟
#
# (101/414) 正在处理: 整租·水泥厂宿舍 4室2厅 南/北
#   驾车: 21.3公里, 48分钟
#   公交: 69分钟
#   步行: 20.0公里, 266分钟
#
# (102/414) 正在处理: 整租·金科博翠山 3室1厅 南
#   驾车: 13.4公里, 38分钟
#   公交: 48分钟
#   步行: 13.0公里, 174分钟
#
# (103/414) 正在处理: 整租·南宁中华路高层职工住宅综合楼 3室2厅 东南
#   驾车: 2.1公里, 13分钟
#   公交: 12分钟
#   步行: 1.4公里, 19分钟
#
# (104/414) 正在处理: 整租·金源CBD现代城 7室3厅 南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (105/414) 正在处理: 整租·金科博翠山 4室2厅 南
#   驾车: 13.4公里, 38分钟
#   公交: 48分钟
#   步行: 13.0公里, 174分钟
#
# (106/414) 正在处理: 整租·天誉花园7组团 2室1厅 南
#   驾车: 15.3公里, 44分钟
#   公交: 53分钟
#   步行: 14.2公里, 189分钟
#
# (107/414) 正在处理: 整租·颐华居 3室2厅 北
#   驾车: 9.2公里, 20分钟
#   公交: 25分钟
#   步行: 7.5公里, 100分钟
#
# (108/414) 正在处理: 整租·万科珈蓝 4室2厅 南
#   驾车: 13.2公里, 41分钟
#   公交: 49分钟
#   步行: 11.8公里, 158分钟
#
# (109/414) 正在处理: 整租·彰泰郡 3室2厅 南
#   驾车: 17.4公里, 45分钟
#   公交: 62分钟
#   步行: 15.9公里, 212分钟
#
# (110/414) 正在处理: 整租·锦麟玖玺 3室2厅 南
#   驾车: 13.2公里, 41分钟
#   公交: 49分钟
#   步行: 11.8公里, 158分钟
#
# (111/414) 正在处理: 整租·江悦蓝湾 1室1厅 东南/南
#   驾车: 9.3公里, 32分钟
#   公交: 40分钟
#   步行: 9.4公里, 125分钟
#
# (112/414) 正在处理: 整租·时代茗城 4室2厅 南
#   驾车: 4.1公里, 20分钟
#   公交: 36分钟
#   步行: 3.2公里, 42分钟
#
# (113/414) 正在处理: 整租·广西警察学院教职工宿舍 3室1厅 南
#   驾车: 7.3公里, 24分钟
#   公交: 34分钟
#   步行: 4.9公里, 65分钟
#
# (114/414) 正在处理: 整租·畅春湖山庄 3室2厅 南
#   驾车: 12.2公里, 31分钟
#   公交: 32分钟
#   步行: 7.5公里, 100分钟
#
# (115/414) 正在处理: 整租·中天世纪花园 2室1厅 南
#   驾车: 6.0公里, 24分钟
#   公交: 30分钟
#   步行: 4.6公里, 61分钟
#
# (116/414) 正在处理: 整租·彰泰滨江学府 4室2厅 南/北
#   驾车: 9.9公里, 34分钟
#   公交: 39分钟
#   步行: 8.0公里, 106分钟
#
# (117/414) 正在处理: 整租·云星尚雅名都 3室2厅 南
#   驾车: 6.5公里, 20分钟
#   公交: 38分钟
#   步行: 6.3公里, 84分钟
#
# (118/414) 正在处理: 整租·同人·西湖东郡 3室1厅 东
#   驾车: 11.2公里, 24分钟
#   公交: 34分钟
#   步行: 8.8公里, 117分钟
#
# (119/414) 正在处理: 整租·畅春湖山庄 3室2厅 南
#   驾车: 12.2公里, 31分钟
#   公交: 32分钟
#   步行: 7.5公里, 100分钟
#
# (120/414) 正在处理: 整租·万科金域蓝湾 4室2厅 南
#   驾车: 13.3公里, 38分钟
#   公交: 51分钟
#   步行: 12.8公里, 170分钟
#
# (121/414) 正在处理: 整租·恒大雅苑 3室3厅 东南
#   驾车: 17.6公里, 39分钟
#   公交: 72分钟
#   步行: 14.1公里, 188分钟
#
# (122/414) 正在处理: 整租·梦之岛花园 4室2厅 南
#   驾车: 12.1公里, 37分钟
#   公交: 45分钟
#   步行: 11.2公里, 150分钟
#
# (123/414) 正在处理: 整租·龙光玖誉湖林湖 3室2厅 南
#   驾车: 14.4公里, 42分钟
#   公交: 55分钟
#   步行: 14.1公里, 188分钟
#
# (124/414) 正在处理: 整租·新城悦隽风华 3室2厅 南
#   驾车: 15.3公里, 37分钟
#   公交: 71分钟
#   步行: 15.8公里, 210分钟
#
# (125/414) 正在处理: 整租·桃源湖居 2室1厅 东
#   驾车: 2.6公里, 11分钟
#   公交: 29分钟
#   步行: 2.7公里, 36分钟
#
# (126/414) 正在处理: 整租·万达茂天樾 1室1厅 东南
#   驾车: 14.3公里, 34分钟
#   公交: 68分钟
#   步行: 14.6公里, 195分钟
#
# (127/414) 正在处理: 整租·植物路区信托宿舍 2室1厅 南
#   驾车: 3.4公里, 17分钟
#   公交: 27分钟
#   步行: 3.2公里, 43分钟
#
# (128/414) 正在处理: 整租·东盟世纪村 2室2厅 南
#   驾车: 6.7公里, 27分钟
#   公交: 52分钟
#   步行: 6.3公里, 84分钟
#
# (129/414) 正在处理: 整租·广源悦府 3室2厅 东南
#   驾车: 11.3公里, 34分钟
#   公交: 46分钟
#   步行: 11.0公里, 147分钟
#
# (130/414) 正在处理: 整租·塞纳维拉花园 4室2厅 错层 南
#   驾车: 9.9公里, 33分钟
#   公交: 35分钟
#   步行: 9.9公里, 132分钟
#
# (131/414) 正在处理: 整租·云星城 1室0厅 东南
#   驾车: 2.1公里, 9分钟
#   公交: 11分钟
#   步行: 2.0公里, 27分钟
#
# (132/414) 正在处理: 整租·亿鼎安吉商业广场 1室1厅 北
#   驾车: 7.8公里, 25分钟
#   公交: 29分钟
#   步行: 6.8公里, 90分钟
#
# (133/414) 正在处理: 整租·幸福里 2室2厅 南
#   驾车: 8.3公里, 37分钟
#   公交: 29分钟
#   步行: 8.2公里, 110分钟
#
# (134/414) 正在处理: 整租·桂盐大厦 4室2厅 东南
#   驾车: 6.0公里, 27分钟
#   公交: 20分钟
#   步行: 5.8公里, 77分钟
#
# (135/414) 正在处理: 整租·凯业花园 4室2厅 南/北
#   驾车: 6.3公里, 25分钟
#   公交: 38分钟
#   步行: 5.3公里, 71分钟
#
# (136/414) 正在处理: 整租·光明·澜湾九里 3室2厅 东南
#   驾车: 12.2公里, 40分钟
#   公交: 42分钟
#   步行: 11.8公里, 158分钟
#
# (137/414) 正在处理: 整租·和润园 4室2厅 南
#   驾车: 10.9公里, 41分钟
#   公交: 42分钟
#   步行: 9.8公里, 130分钟
#
# (138/414) 正在处理: 整租·绿地中央广场二期 3室2厅 南
#   驾车: 7.7公里, 30分钟
#   公交: 53分钟
#   步行: 6.2公里, 82分钟
#
# (139/414) 正在处理: 整租·金州琅园 1室0厅 东南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (140/414) 正在处理: 整租·万科金域蓝湾 3室2厅 南
#   驾车: 13.3公里, 38分钟
#   公交: 51分钟
#   步行: 12.8公里, 170分钟
#
# (141/414) 正在处理: 整租·万昌南湖景园 3室2厅 南/北
#   驾车: 5.5公里, 24分钟
#   公交: 33分钟
#   步行: 5.1公里, 68分钟
#
# (142/414) 正在处理: 整租·五象航洋城 2室1厅 南
#   驾车: 10.8公里, 40分钟
#   公交: 34分钟
#   步行: 9.2公里, 123分钟
#
# (143/414) 正在处理: 整租·雅典国际 1室1厅 复式 东
#   驾车: 10.5公里, 35分钟
#   公交: 31分钟
#   步行: 10.0公里, 133分钟
#
# (144/414) 正在处理: 整租·五洲国际 2室2厅 复式 东南
#   驾车: 8.7公里, 41分钟
#   公交: 33分钟
#   步行: 8.8公里, 118分钟
#
# (145/414) 正在处理: 整租·广西水产畜牧学校职工住宅楼 6室2厅 南
#   驾车: 5.1公里, 20分钟
#   公交: 41分钟
#   步行: 5.2公里, 69分钟
#
# (146/414) 正在处理: 整租·国信信托宿舍 3室1厅 东南
#   驾车: 5.7公里, 26分钟
#   公交: 24分钟
#   步行: 5.7公里, 76分钟
#
# (147/414) 正在处理: 整租·荣和·东盟国际 2室1厅 南
#   驾车: 8.5公里, 31分钟
#   公交: 24分钟
#   步行: 8.7公里, 116分钟
#
# (148/414) 正在处理: 整租·彰泰江景湾 3室2厅 南
#   驾车: 20.8公里, 44分钟
#   公交: 92分钟
#   步行: 19.0公里, 253分钟
#
# (149/414) 正在处理: 整租·地王国际商会中心 4室1厅 东南
#   驾车: 5.6公里, 25分钟
#   公交: 22分钟
#   步行: 5.6公里, 75分钟
#
# (150/414) 正在处理: 合租·广源大都会二期 4居室 东南/南卧
#   驾车: 12.0公里, 40分钟
#   公交: 42分钟
#   步行: 10.6公里, 141分钟
#
# (151/414) 正在处理: 整租·万科金域滨江 4室2厅 南/北
#   驾车: 17.7公里, 39分钟
#   公交: 86分钟
#   步行: 17.2公里, 230分钟
#
# (152/414) 正在处理: 整租·利海亚洲国际 1室1厅 东南/南
#   驾车: 8.7公里, 43分钟
#   公交: 31分钟
#   步行: 8.6公里, 114分钟
#
# (153/414) 正在处理: 整租·金之岛城市广场住宅 1室1厅 南
#   驾车: 2.4公里, 13分钟
#   公交: 17分钟
#   步行: 1.4公里, 18分钟
#
# (154/414) 正在处理: 整租·半岛融园小区 4室2厅 南/北
#   驾车: 8.2公里, 26分钟
#   公交: 50分钟
#   步行: 7.0公里, 94分钟
#
# (155/414) 正在处理: 整租·金旺角 1室0厅 南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (156/414) 正在处理: 整租·彰泰城B区 1室0厅 南
#   驾车: 11.0公里, 40分钟
#   公交: 41分钟
#   步行: 10.6公里, 141分钟
#
# (157/414) 正在处理: 整租·青秀万达 1室1厅 东南
#   驾车: 21.3公里, 48分钟
#   公交: 69分钟
#   步行: 20.0公里, 266分钟
#
# (158/414) 正在处理: 整租·利海亚洲国际B区 1室0厅 南
#   驾车: 8.5公里, 43分钟
#   公交: 32分钟
#   步行: 8.4公里, 113分钟
#
# (159/414) 正在处理: 整租·大唐盛世 6室2厅 南
#   驾车: 19.8公里, 44分钟
#   公交: 83分钟
#   步行: 19.5公里, 260分钟
#
# (160/414) 正在处理: 整租·南湖御景 3室1厅 南
#   驾车: 3.0公里, 15分钟
#   公交: 31分钟
#   步行: 2.8公里, 38分钟
#
# (161/414) 正在处理: 整租·向南居·金溪园 1室1厅 东北
#   驾车: 8.0公里, 33分钟
#   公交: 41分钟
#   步行: 7.2公里, 97分钟
#
# (162/414) 正在处理: 整租·盛世龙腾 2室2厅 南
#   驾车: 8.5公里, 31分钟
#   公交: 49分钟
#   步行: 7.7公里, 103分钟
#
# (163/414) 正在处理: 整租·保利领秀前城秀程府 4室2厅 东南
#   驾车: 13.0公里, 44分钟
#   公交: 54分钟
#   步行: 12.8公里, 171分钟
#
# (164/414) 正在处理: 整租·龙域香醍半岛 4室2厅 南/北
#   驾车: 20.1公里, 44分钟
#   公交: 82分钟
#   步行: 18.9公里, 252分钟
#
# (165/414) 正在处理: 整租·前海人寿金融中心 6室1厅 东北
#   驾车: 10.5公里, 38分钟
#   公交: 37分钟
#   步行: 10.4公里, 139分钟
#
# (166/414) 正在处理: 整租·中房·翡翠湾 2室2厅 南
#   驾车: 9.6公里, 37分钟
#   公交: 47分钟
#   步行: 9.2公里, 123分钟
#
# (167/414) 正在处理: 整租·恒大苹果园·金色阳光 4室1厅 东南
#   驾车: 8.2公里, 33分钟
#   公交: 48分钟
#   步行: 7.5公里, 100分钟
#
# (168/414) 正在处理: 整租·中房·翡翠湾 1室2厅 南
#   驾车: 9.6公里, 37分钟
#   公交: 47分钟
#   步行: 9.2公里, 123分钟
#
# (169/414) 正在处理: 整租·梦之岛花园 3室2厅 南/北
#   驾车: 12.1公里, 36分钟
#   公交: 45分钟
#   步行: 11.2公里, 150分钟
#
# (170/414) 正在处理: 整租·檀府印象檀熙 4室2厅 南/北
#   驾车: 15.4公里, 42分钟
#   公交: 64分钟
#   步行: 14.7公里, 196分钟
#
# (171/414) 正在处理: 整租·世洋大厦 2室2厅 北
#   驾车: 9.7公里, 33分钟
#   公交: 30分钟
#   步行: 9.0公里, 120分钟
#
# (172/414) 正在处理: 整租·摩卡生活馆 1室1厅 东
#   驾车: 2.2公里, 9分钟
#   公交: 16分钟
#   步行: 1.6公里, 22分钟
#
# (173/414) 正在处理: 整租·凯丰大厦 1室0厅 北
#   驾车: 2.6公里, 13分钟
#   公交: 24分钟
#   步行: 2.2公里, 30分钟
#
# (174/414) 正在处理: 整租·利海亚洲国际 1室1厅 东南/南
#   驾车: 8.7公里, 43分钟
#   公交: 31分钟
#   步行: 8.6公里, 114分钟
#
# (175/414) 正在处理: 整租·金之岛城市广场住宅 1室1厅 南
#   驾车: 2.4公里, 13分钟
#   公交: 17分钟
#   步行: 1.4公里, 18分钟
#
# (176/414) 正在处理: 整租·金旺角 1室0厅 南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (177/414) 正在处理: 整租·彰泰城B区 1室0厅 南
#   驾车: 11.0公里, 39分钟
#   公交: 41分钟
#   步行: 10.6公里, 141分钟
#
# (178/414) 正在处理: 整租·大唐盛世 6室2厅 南
#   驾车: 19.8公里, 44分钟
#   公交: 83分钟
#   步行: 19.5公里, 260分钟
#
# (179/414) 正在处理: 整租·向南居·金溪园 1室1厅 东北
#   驾车: 8.0公里, 34分钟
#   公交: 41分钟
#   步行: 7.2公里, 97分钟
#
# (180/414) 正在处理: 整租·保利领秀前城秀程府 4室2厅 东南
#   驾车: 13.0公里, 45分钟
#   公交: 54分钟
#   步行: 12.8公里, 171分钟
#
# (181/414) 正在处理: 整租·龙域香醍半岛 4室2厅 南/北
#   驾车: 20.1公里, 44分钟
#   公交: 82分钟
#   步行: 18.9公里, 252分钟
#
# (182/414) 正在处理: 整租·前海人寿金融中心 10室2厅 东南
#   驾车: 10.5公里, 38分钟
#   公交: 37分钟
#   步行: 10.4公里, 139分钟
#
# (183/414) 正在处理: 整租·中房·翡翠湾 1室2厅 南
#   驾车: 9.6公里, 38分钟
#   公交: 47分钟
#   步行: 9.2公里, 123分钟
#
# (184/414) 正在处理: 整租·檀府印象檀熙 4室2厅 南/北
#   驾车: 15.4公里, 42分钟
#   公交: 64分钟
#   步行: 14.7公里, 196分钟
#
# (185/414) 正在处理: 整租·世洋大厦 2室2厅 北
#   驾车: 9.7公里, 33分钟
#   公交: 30分钟
#   步行: 9.0公里, 120分钟
#
# (186/414) 正在处理: 整租·凯丰大厦 1室0厅 北
#   驾车: 2.6公里, 13分钟
#   公交: 24分钟
#   步行: 2.2公里, 30分钟
#
# (187/414) 正在处理: 整租·绿城画卷 1室0厅 东南
#   驾车: 5.0公里, 23分钟
#   公交: 23分钟
#   步行: 4.9公里, 65分钟
#
# (188/414) 正在处理: 整租·悦桂绿地新世界 3室2厅 南
#   驾车: 34.2公里, 57分钟
#   公交: 97分钟
#   步行: 32.2公里, 429分钟
#
# (189/414) 正在处理: 整租·金玖世家北区 4室2厅 南/北
#   驾车: 13.1公里, 38分钟
#   公交: 28分钟
#   步行: 12.3公里, 164分钟
#
# (190/414) 正在处理: 整租·阳光100 2室1厅 南
#   驾车: 5.9公里, 23分钟
#   公交: 38分钟
#   步行: 4.0公里, 53分钟
#
# (191/414) 正在处理: 整租·金和大厦 2室1厅 东南
#   驾车: 4.0公里, 20分钟
#   公交: 21分钟
#   步行: 3.8公里, 50分钟
#
# (192/414) 正在处理: 整租·旺南花园小区 4室2厅 南
#   驾车: 6.2公里, 29分钟
#   公交: 25分钟
#   步行: 6.1公里, 81分钟
#
# (193/414) 正在处理: 整租·金和大厦 1室0厅 南
#   驾车: 4.0公里, 20分钟
#   公交: 21分钟
#   步行: 3.8公里, 50分钟
#
# (194/414) 正在处理: 整租·荣和悦澜山 4室1厅 南/北
#   驾车: 11.8公里, 33分钟
#   公交: 37分钟
#   步行: 7.1公里, 95分钟
#
# (195/414) 正在处理: 整租·阳光100上东国际 1室0厅 东
#   驾车: 9.9公里, 32分钟
#   公交: 29分钟
#   步行: 9.4公里, 126分钟
#
# (196/414) 正在处理: 整租·山水花都秀竹花园 3室3厅 西南
#   驾车: 6.1公里, 23分钟
#   公交: 30分钟
#   步行: 6.0公里, 81分钟
#
# (197/414) 正在处理: 整租·银海华廷 3室2厅 南
#   驾车: 11.2公里, 37分钟
#   公交: 28分钟
#   步行: 10.9公里, 146分钟
#
# (198/414) 正在处理: 整租·东方花园 3室2厅 东南
#   驾车: 5.3公里, 23分钟
#   公交: 23分钟
#   步行: 5.4公里, 71分钟
#
# (199/414) 正在处理: 整租·龙光世纪中心 1室1厅 南
#   驾车: 8.7公里, 40分钟
#   公交: 27分钟
#   步行: 8.7公里, 116分钟
#
# (200/414) 正在处理: 整租·枫林蓝岸 5室2厅 复式 南
#   驾车: 9.9公里, 33分钟
#   公交: 36分钟
#   步行: 10.2公里, 136分钟
#
# (201/414) 正在处理: 整租·福满瑞园 4室2厅 复式 南
#   驾车: 8.7公里, 26分钟
#   公交: 48分钟
#   步行: 7.9公里, 105分钟
#
# (202/414) 正在处理: 整租·台湾街宜兰湾 1室1厅 东南
#   驾车: 4.1公里, 16分钟
#   公交: 35分钟
#   步行: 3.8公里, 51分钟
#
# (203/414) 正在处理: 整租·启迪亮 4室2厅 南/北
#   驾车: 18.3公里, 46分钟
#   公交: 65分钟
#   步行: 18.1公里, 241分钟
#
# (204/414) 正在处理: 整租·金玖世家北区 4室2厅 北
#   驾车: 13.1公里, 38分钟
#   公交: 28分钟
#   步行: 12.3公里, 164分钟
#
# (205/414) 正在处理: 整租·绿城春江明月 4室2厅 东南
#   驾车: 13.2公里, 42分钟
#   公交: 52分钟
#   步行: 12.2公里, 163分钟
#
# (206/414) 正在处理: 整租·圣展独立公社 1室1厅 西/西北
#   驾车: 5.7公里, 26分钟
#   公交: 24分钟
#   步行: 5.7公里, 76分钟
#
# (207/414) 正在处理: 整租·荣和山水绿城B1组团 2室2厅 南
#   驾车: 5.8公里, 25分钟
#   公交: 36分钟
#   步行: 5.2公里, 70分钟
#
# (208/414) 正在处理: 整租·幸福里 4室2厅 南
#   驾车: 8.3公里, 37分钟
#   公交: 29分钟
#   步行: 8.2公里, 110分钟
#
# (209/414) 正在处理: 整租·中鼎万象东方 1室1厅 北
#   驾车: 7.8公里, 32分钟
#   公交: 22分钟
#   步行: 8.0公里, 107分钟
#
# (210/414) 正在处理: 整租·万科公园里 4室2厅 东/南
#   驾车: 16.3公里, 45分钟
#   公交: 64分钟
#   步行: 14.7公里, 196分钟
#
# (211/414) 正在处理: 整租·广源大都会 3室2厅 南/北
#   驾车: 11.2公里, 39分钟
#   公交: 47分钟
#   步行: 10.7公里, 142分钟
#
# (212/414) 正在处理: 整租·盛湖悦景 4室2厅 南/北
#   驾车: 19.3公里, 43分钟
#   公交: 74分钟
#   步行: 19.3公里, 258分钟
#
# (213/414) 正在处理: 整租·万科金域中央一期 5室2厅 南
#   驾车: 11.2公里, 38分钟
#   公交: 45分钟
#   步行: 10.7公里, 143分钟
#
# (214/414) 正在处理: 整租·彰泰城B区 1室1厅 南
#   驾车: 11.0公里, 40分钟
#   公交: 41分钟
#   步行: 10.6公里, 141分钟
#
# (215/414) 正在处理: 整租·南湖聚宝苑 5室2厅 东南
#   驾车: 5.1公里, 23分钟
#   公交: 19分钟
#   步行: 5.2公里, 69分钟
#
# (216/414) 正在处理: 整租·东葛路18-1汇宇花园 5室2厅 东南
#   驾车: 2.5公里, 10分钟
#   公交: 20分钟
#   步行: 1.6公里, 21分钟
#
# (217/414) 正在处理: 整租·伟业小区 3室2厅 南
#   驾车: 5.6公里, 22分钟
#   公交: 39分钟
#   步行: 4.2公里, 56分钟
#
# (218/414) 正在处理: 整租·凤岭·新新家园A区 4室2厅 南
#   驾车: 9.8公里, 32分钟
#   公交: 34分钟
#   步行: 9.6公里, 128分钟
#
# (219/414) 正在处理: 整租·中房翡翠园一期 3室2厅 北
#   驾车: 10.5公里, 34分钟
#   公交: 35分钟
#   步行: 10.4公里, 138分钟
#
# (220/414) 正在处理: 整租·龙光玖誉城悦城 1室1厅 北
#   驾车: 6.2公里, 23分钟
#   公交: 26分钟
#   步行: 6.2公里, 82分钟
#
# (221/414) 正在处理: 整租·耀凯凤岭1号 1室1厅 东南
#   驾车: 11.0公里, 40分钟
#   公交: 36分钟
#   步行: 8.8公里, 118分钟
#
# (222/414) 正在处理: 整租·宏桂东昇 2室2厅 东南
#   驾车: 13.1公里, 42分钟
#   公交: 65分钟
#   步行: 13.7公里, 182分钟
#
# (223/414) 正在处理: 整租·平安家园 3室2厅 南/北
#   驾车: 7.5公里, 30分钟
#   公交: 31分钟
#   步行: 7.6公里, 102分钟
#
# (224/414) 正在处理: 整租·盛邦珑湖 1室0厅 南
#   驾车: 12.7公里, 37分钟
#   公交: 63分钟
#   步行: 12.0公里, 160分钟
#
# (225/414) 正在处理: 整租·宏桂东昇 2室2厅 南
#   驾车: 13.1公里, 42分钟
#   公交: 65分钟
#   步行: 13.7公里, 182分钟
#
# (226/414) 正在处理: 整租·金河中心 4室2厅 南
#   驾车: 14.3公里, 34分钟
#   公交: 48分钟
#   步行: 8.6公里, 115分钟
#
# (227/414) 正在处理: 整租·大唐盛世 3室2厅 北
#   驾车: 19.8公里, 44分钟
#   公交: 83分钟
#   步行: 19.5公里, 260分钟
#
# (228/414) 正在处理: 整租·幸福里 5室3厅 南
#   驾车: 8.3公里, 37分钟
#   公交: 29分钟
#   步行: 8.2公里, 110分钟
#
# (229/414) 正在处理: 整租·凤岭山语城 1室1厅 西北
#   驾车: 11.5公里, 37分钟
#   公交: 45分钟
#   步行: 11.1公里, 148分钟
#
# (230/414) 正在处理: 整租·五象世茂中心 1室1厅 南
#   驾车: 13.2公里, 42分钟
#   公交: 52分钟
#   步行: 12.2公里, 163分钟
#
# (231/414) 正在处理: 整租·阳光100上东国际 3室2厅 西
#   驾车: 9.9公里, 32分钟
#   公交: 29分钟
#   步行: 9.4公里, 126分钟
#
# (232/414) 正在处理: 整租·利海亚洲国际B区 4室2厅 东
#   驾车: 8.5公里, 43分钟
#   公交: 32分钟
#   步行: 8.4公里, 113分钟
#
# (233/414) 正在处理: 整租·瀚林学府二期 2室2厅 南
#   驾车: 5.3公里, 22分钟
#   公交: 19分钟
#   步行: 4.9公里, 65分钟
#
# (234/414) 正在处理: 整租·汇春名庭东区 4室2厅 东南
#   驾车: 5.6公里, 26分钟
#   公交: 26分钟
#   步行: 5.7公里, 75分钟
#
# (235/414) 正在处理: 整租·古城馨园 2室1厅 南
#   驾车: 2.4公里, 10分钟
#   公交: 19分钟
#   步行: 2.6公里, 34分钟
#
# (236/414) 正在处理: 整租·万科魅力之城 4室1厅 南
#   驾车: 15.6公里, 44分钟
#   公交: 57分钟
#   步行: 15.4公里, 206分钟
#
# (237/414) 正在处理: 整租·中房翡翠园一期 2室2厅 南/北
#   驾车: 10.5公里, 34分钟
#   公交: 35分钟
#   步行: 10.4公里, 138分钟
#
# (238/414) 正在处理: 整租·湖江公寓 5室2厅 南/北
#   驾车: 5.5公里, 20分钟
#   公交: 38分钟
#   步行: 3.3公里, 44分钟
#
# (239/414) 正在处理: 整租·印象·愉景湾 4室2厅 东南
#   驾车: 20.9公里, 47分钟
#   公交: 79分钟
#   步行: 19.6公里, 261分钟
#
# (240/414) 正在处理: 整租·龙光国际 3室1厅 西北
#   驾车: 13.2公里, 42分钟
#   公交: 52分钟
#   步行: 12.2公里, 163分钟
#
# (241/414) 正在处理: 整租·龙光国际 3室1厅 西北
#   驾车: 13.2公里, 42分钟
#   公交: 52分钟
#   步行: 12.2公里, 163分钟
#
# (242/414) 正在处理: 整租·外滩新城 3室1厅 南
#   驾车: 1.4公里, 7分钟
#   公交: 18分钟
#   步行: 1.4公里, 18分钟
#
# (243/414) 正在处理: 整租·东葛华都 1室1厅 南
#   驾车: 2.0公里, 10分钟
#   公交: 23分钟
#   步行: 1.9公里, 26分钟
#
# (244/414) 正在处理: 整租·白鹭北城白鹭郡 4室2厅 南/北
#   驾车: 11.5公里, 30分钟
#   公交: 38分钟
#   步行: 7.4公里, 99分钟
#
# (245/414) 正在处理: 整租·凯丰大厦 1室1厅 南
#   驾车: 2.6公里, 13分钟
#   公交: 24分钟
#   步行: 2.2公里, 30分钟
#
# (246/414) 正在处理: 整租·檀府印象檀熙 4室2厅 南/北
#   驾车: 15.4公里, 42分钟
#   公交: 64分钟
#   步行: 14.7公里, 196分钟
#
# (247/414) 正在处理: 整租·威宁青运村 5室2厅 北
#   驾车: 12.3公里, 39分钟
#   公交: 51分钟
#   步行: 12.0公里, 161分钟
#
# (248/414) 正在处理: 整租·龙光世纪中心 1室1厅 南
#   驾车: 8.7公里, 40分钟
#   公交: 27分钟
#   步行: 8.7公里, 116分钟
#
# (249/414) 正在处理: 整租·嘉和城温莎北郡 3室2厅 南
#   驾车: 24.9公里, 56分钟
#   公交: 102分钟
#   步行: 19.9公里, 266分钟
#
# (250/414) 正在处理: 整租·中海哈罗学府 3室2厅 南
#   驾车: 19.9公里, 44分钟
#   公交: 78分钟
#   步行: 19.4公里, 258分钟
#
# (251/414) 正在处理: 整租·锦绣花园 1室1厅 南
#   驾车: 2.0公里, 9分钟
#   公交: 17分钟
#   步行: 1.6公里, 21分钟
#
# (252/414) 正在处理: 整租·龙光天瀛 3室2厅 南/北
#   驾车: 14.5公里, 40分钟
#   公交: 49分钟
#   步行: 13.6公里, 182分钟
#
# (253/414) 正在处理: 整租·万达广场 1室1厅 南
#   驾车: 4.2公里, 19分钟
#   公交: 13分钟
#   步行: 4.2公里, 56分钟
#
# (254/414) 正在处理: 整租·阳光城时代中心 1室1厅 东
#   驾车: 12.2公里, 39分钟
#   公交: 50分钟
#   步行: 12.1公里, 162分钟
#
# (255/414) 正在处理: 整租·云星钱隆首府B组团 1室1厅 南
#   驾车: 9.7公里, 32分钟
#   公交: 39分钟
#   步行: 9.6公里, 128分钟
#
# (256/414) 正在处理: 整租·广源国际社区 4室2厅 东南
#   驾车: 8.2公里, 31分钟
#   公交: 40分钟
#   步行: 6.8公里, 90分钟
#
# (257/414) 正在处理: 整租·翠竹小区 4室2厅 南/北
#   驾车: 10.8公里, 35分钟
#   公交: 42分钟
#   步行: 10.9公里, 145分钟
#
# (258/414) 正在处理: 整租·荣和大地二组团 4室2厅 东南
#   驾车: 10.8公里, 33分钟
#   公交: 48分钟
#   步行: 9.5公里, 127分钟
#
# (259/414) 正在处理: 整租·江景华廷 3室1厅 东南
#   驾车: 20.6公里, 48分钟
#   公交: 66分钟
#   步行: 19.3公里, 257分钟
#
# (260/414) 正在处理: 整租·青年国际 2室1厅 复式 东南
#   驾车: 4.1公里, 19分钟
#   公交: 35分钟
#   步行: 4.1公里, 54分钟
#
# (261/414) 正在处理: 整租·盛科城 3室1厅 南/北
#   驾车: 10.7公里, 34分钟
#   公交: 46分钟
#   步行: 10.4公里, 139分钟
#
# (262/414) 正在处理: 整租·万科金域蓝湾 4室2厅 西南
#   驾车: 13.3公里, 38分钟
#   公交: 51分钟
#   步行: 12.8公里, 170分钟
#
# (263/414) 正在处理: 整租·盛湖悦景 4室2厅 东南/西南
#   驾车: 19.3公里, 43分钟
#   公交: 77分钟
#   步行: 19.3公里, 258分钟
#
# (264/414) 正在处理: 整租·五象澜庭府沁苑 4室2厅 南
#   驾车: 15.8公里, 42分钟
#   公交: 61分钟
#   步行: 14.3公里, 191分钟
#
# (265/414) 正在处理: 整租·安吉万达华府 4室1厅 南/北
#   驾车: 8.5公里, 27分钟
#   公交: 27分钟
#   步行: 6.8公里, 91分钟
#
# (266/414) 正在处理: 整租·大唐臻观 4室2厅 东南/南
#   驾车: 11.3公里, 36分钟
#   公交: 51分钟
#   步行: 10.8公里, 144分钟
#
# (267/414) 正在处理: 整租·恒大名都 3室2厅 南/北
#   驾车: 7.0公里, 25分钟
#   公交: 28分钟
#   步行: 7.1公里, 95分钟
#
# (268/414) 正在处理: 整租·东盟华府 4室2厅 东南
#   驾车: 11.9公里, 28分钟
#   公交: 59分钟
#   步行: 10.1公里, 135分钟
#
# (269/414) 正在处理: 整租·永凯春晖花园西C区 4室2厅 南
#   驾车: 8.1公里, 34分钟
#   公交: 30分钟
#   步行: 8.0公里, 107分钟
#
# (270/414) 正在处理: 整租·龙域香醍半岛 3室2厅 南/北
#   驾车: 20.1公里, 44分钟
#   公交: 82分钟
#   步行: 18.9公里, 252分钟
#
# (271/414) 正在处理: 整租·金湖帝景 2室1厅 南
#   驾车: 6.0公里, 30分钟
#   公交: 23分钟
#   步行: 6.0公里, 80分钟
#
# (272/414) 正在处理: 整租·逸景園 3室2厅 东南/南
#   驾车: 5.3公里, 23分钟
#   公交: 25分钟
#   步行: 5.5公里, 73分钟
#
# (273/414) 正在处理: 整租·西江大厦 3室2厅 南
#   驾车: 5.9公里, 26分钟
#   公交: 18分钟
#   步行: 5.6公里, 75分钟
#
# (274/414) 正在处理: 整租·中房翡翠园一期 3室2厅 东南
#   驾车: 10.5公里, 33分钟
#   公交: 35分钟
#   步行: 10.4公里, 138分钟
#
# (275/414) 正在处理: 整租·广西民族宫 1室0厅 东/东南
#   驾车: 1.7公里, 6分钟
#   公交: 11分钟
#   步行: 1.6公里, 22分钟
#
# (276/414) 正在处理: 整租·龙光玖珑臺 4室2厅 东南
#   驾车: 16.6公里, 38分钟
#   公交: 76分钟
#   步行: 16.9公里, 225分钟
#
# (277/414) 正在处理: 整租·五洲国际 3室2厅 复式 东南
#   驾车: 8.7公里, 41分钟
#   公交: 33分钟
#   步行: 8.8公里, 118分钟
#
# (278/414) 正在处理: 整租·自治区人事厅宿舍 3室2厅 南
#   驾车: 3.1公里, 13分钟
#   公交: 25分钟
#   步行: 2.7公里, 37分钟
#
# (279/414) 正在处理: 整租·华兴大厦 4室2厅 东南
#   驾车: 3.4公里, 14分钟
#   公交: 16分钟
#   步行: 2.9公里, 38分钟
#
# (280/414) 正在处理: 整租·盛湖悦景 4室2厅 南/北
#   驾车: 19.3公里, 43分钟
#   公交: 77分钟
#   步行: 19.3公里, 258分钟
#
# (281/414) 正在处理: 整租·檀府印象檀熙 3室2厅 南
#   驾车: 15.4公里, 42分钟
#   公交: 64分钟
#   步行: 14.7公里, 196分钟
#
# (282/414) 正在处理: 整租·东方曼哈顿 1室1厅 西
#   驾车: 5.6公里, 24分钟
#   公交: 20分钟
#   步行: 5.8公里, 77分钟
#
# (283/414) 正在处理: 整租·绿地中央广场 1室0厅 东南
#   驾车: 7.7公里, 29分钟
#   公交: 53分钟
#   步行: 6.2公里, 82分钟
#
# (284/414) 正在处理: 整租·绿地中央广场 1室0厅 东南
#   驾车: 7.7公里, 29分钟
#   公交: 53分钟
#   步行: 6.2公里, 82分钟
#
# (285/414) 正在处理: 整租·塞纳维拉花园 4室2厅 南/北
#   驾车: 9.9公里, 33分钟
#   公交: 35分钟
#   步行: 9.9公里, 132分钟
#
# (286/414) 正在处理: 整租·丰业·柠檬宿 1室0厅 北
#   驾车: 4.4公里, 18分钟
#   公交: 16分钟
#   步行: 3.5公里, 46分钟
#
# (287/414) 正在处理: 整租·龙光玖誉湖御湖 4室2厅 南/北
#   驾车: 14.8公里, 42分钟
#   公交: 51分钟
#   步行: 13.8公里, 184分钟
#
# (288/414) 正在处理: 整租·恒大御景 4室2厅 南/北
#   驾车: 14.1公里, 38分钟
#   公交: 58分钟
#   步行: 12.1公里, 162分钟
#
# (289/414) 正在处理: 整租·东葛华都 1室1厅 东南
#   驾车: 2.0公里, 11分钟
#   公交: 23分钟
#   步行: 1.9公里, 26分钟
#
# (290/414) 正在处理: 整租·新竹小区 4室1厅 南
#   驾车: 3.9公里, 19分钟
#   公交: 21分钟
#   步行: 3.6公里, 47分钟
#
# (291/414) 正在处理: 整租·万科魅力之城 3室2厅 东南
#   驾车: 15.6公里, 44分钟
#   公交: 57分钟
#   步行: 15.4公里, 206分钟
#
# (292/414) 正在处理: 整租·富宁新兴苑 4室2厅 南/北
#   驾车: 7.8公里, 19分钟
#   公交: 44分钟
#   步行: 6.5公里, 87分钟
#
# (293/414) 正在处理: 整租·天立TT国际 1室1厅 南
#   驾车: 6.6公里, 29分钟
#   公交: 31分钟
#   步行: 6.7公里, 89分钟
#
# (294/414) 正在处理: 整租·龙光玖誉湖澜湖 3室2厅 南
#   驾车: 14.4公里, 42分钟
#   公交: 55分钟
#   步行: 14.1公里, 188分钟
#
# (295/414) 正在处理: 整租·龙光玖珑臺 4室2厅 南
#   驾车: 16.6公里, 38分钟
#   公交: 76分钟
#   步行: 16.9公里, 225分钟
#
# (296/414) 正在处理: 整租·联盟新城 4室2厅 复式 东南
#   驾车: 9.9公里, 38分钟
#   公交: 40分钟
#   步行: 9.0公里, 120分钟
#
# (297/414) 正在处理: 整租·烟草公司生活区 3室1厅 东南
#   驾车: 5.9公里, 22分钟
#   公交: 38分钟
#   步行: 4.0公里, 53分钟
#
# (298/414) 正在处理: 整租·融创九棠府二期 4室2厅 南
#   驾车: 15.1公里, 42分钟
#   公交: 62分钟
#   步行: 14.2公里, 189分钟
#
# (299/414) 正在处理: 整租·中房琅东小区 3室2厅 南
#   驾车: 6.7公里, 28分钟
#   公交: 33分钟
#   步行: 7.0公里, 93分钟
#
# (300/414) 正在处理: 整租·天誉半岛 5室2厅 东南
#   驾车: 15.3公里, 39分钟
#   公交: 46分钟
#   步行: 14.7公里, 196分钟
#
# (301/414) 正在处理: 整租·印象·愉景湾 4室2厅 南
#   驾车: 20.9公里, 47分钟
#   公交: 80分钟
#   步行: 19.6公里, 261分钟
#
# (302/414) 正在处理: 整租·蓝宝国际 1室1厅 南
#   驾车: 5.2公里, 21分钟
#   公交: 36分钟
#   步行: 5.0公里, 66分钟
#
# (303/414) 正在处理: 整租·太阳广场 4室2厅 东南
#   驾车: 2.1公里, 11分钟
#   公交: 19分钟
#   步行: 1.1公里, 14分钟
#
# (304/414) 正在处理: 整租·龙光世纪中心 3室1厅 东南
#   驾车: 8.7公里, 40分钟
#   公交: 27分钟
#   步行: 8.7公里, 116分钟
#
# (305/414) 正在处理: 整租·霖峰壹号3组团 1室1厅 东南
#   驾车: 13.4公里, 34分钟
#   公交: 45分钟
#   步行: 8.9公里, 118分钟
#
# (306/414) 正在处理: 整租·青秀万达 1室0厅 东
#   驾车: 21.3公里, 49分钟
#   公交: 69分钟
#   步行: 20.0公里, 266分钟
#
# (307/414) 正在处理: 整租·澜湾九里二期 3室2厅 南
#   驾车: 12.2公里, 35分钟
#   公交: 38分钟
#   步行: 12.1公里, 161分钟
#
# (308/414) 正在处理: 整租·碧园南城故事 3室2厅 南
#   驾车: 11.6公里, 30分钟
#   公交: 38分钟
#   步行: 10.3公里, 137分钟
#
# (309/414) 正在处理: 整租·润和谷 3室2厅 南
#   驾车: 15.3公里, 46分钟
#   公交: 58分钟
#   步行: 15.1公里, 201分钟
#
# (310/414) 正在处理: 整租·时代天骄 1室1厅 南
#   驾车: 5.3公里, 21分钟
#   公交: 17分钟
#   步行: 4.7公里, 63分钟
#
# (311/414) 正在处理: 整租·金碧苑小区 3室2厅 东南
#   驾车: 5.7公里, 25分钟
#   公交: 20分钟
#   步行: 5.8公里, 77分钟
#
# (312/414) 正在处理: 整租·园湖南路34号 4室2厅 南
#   驾车: 3.2公里, 15分钟
#   公交: 15分钟
#   步行: 3.3公里, 44分钟
#
# (313/414) 正在处理: 整租·悦桂绿地新世界 3室2厅 南
#   驾车: 34.2公里, 56分钟
#   公交: 97分钟
#   步行: 32.2公里, 429分钟
#
# (314/414) 正在处理: 整租·中房翡翠园一期 4室2厅 南
#   驾车: 10.5公里, 34分钟
#   公交: 35分钟
#   步行: 10.4公里, 138分钟
#
# (315/414) 正在处理: 整租·万科金域中央二期 3室2厅 南
#   驾车: 11.2公里, 38分钟
#   公交: 45分钟
#   步行: 10.7公里, 143分钟
#
# (316/414) 正在处理: 整租·天誉城 1室1厅 南
#   驾车: 15.6公里, 44分钟
#   公交: 50分钟
#   步行: 14.9公里, 198分钟
#
# (317/414) 正在处理: 整租·金湖帝景 1室0厅 南
#   驾车: 6.0公里, 29分钟
#   公交: 23分钟
#   步行: 6.0公里, 80分钟
#
# (318/414) 正在处理: 整租·农行家属院住宅区 4室2厅 南/北
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (319/414) 正在处理: 整租·昊然风景 3室2厅 南
#   驾车: 10.3公里, 33分钟
#   公交: 27分钟
#   步行: 9.8公里, 130分钟
#
# (320/414) 正在处理: 整租·金菲豪园 3室2厅 南/北
#   驾车: 10.6公里, 37分钟
#   公交: 46分钟
#   步行: 10.0公里, 134分钟
#
# (321/414) 正在处理: 整租·边防警官公寓 4室2厅 南
#   驾车: 14.4公里, 34分钟
#   公交: 39分钟
#   步行: 10.4公里, 138分钟
#
# (322/414) 正在处理: 整租·五象世茂中心 1室1厅 南
#   驾车: 13.2公里, 42分钟
#   公交: 52分钟
#   步行: 12.2公里, 163分钟
#
# (323/414) 正在处理: 整租·天昌东盟中央城B区 2室1厅 南/北
#   驾车: 10.5公里, 38分钟
#   公交: 40分钟
#   步行: 9.1公里, 121分钟
#
# (324/414) 正在处理: 整租·枫林蓝岸 4室2厅 南
#   驾车: 9.9公里, 33分钟
#   公交: 36分钟
#   步行: 10.2公里, 136分钟
#
# (325/414) 正在处理: 整租·国贸中心 1室1厅 南
#   驾车: 0.6公里, 3分钟
#   公交: 15分钟
#   步行: 0.6公里, 8分钟
#
# (326/414) 正在处理: 整租·又一居公寓 1室0厅 东南
#   驾车: 3.6公里, 16分钟
#   公交: 12分钟
#   步行: 3.1公里, 42分钟
#
# (327/414) 正在处理: 整租·国贸中心 3室2厅 南
#   驾车: 0.6公里, 3分钟
#   公交: 15分钟
#   步行: 0.6公里, 8分钟
#
# (328/414) 正在处理: 整租·宝能五象湖一号 3室2厅 南
#   驾车: 13.2公里, 40分钟
#   公交: 49分钟
#   步行: 11.8公里, 158分钟
#
# (329/414) 正在处理: 整租·区水利厅机关大院 3室2厅 南
#   驾车: 2.9公里, 14分钟
#   公交: 34分钟
#   步行: 2.7公里, 36分钟
#
# (330/414) 正在处理: 整租·霖峰壹號2组团 3室2厅 南
#   驾车: 12.5公里, 33分钟
#   公交: 44分钟
#   步行: 8.5公里, 113分钟
#
# (331/414) 正在处理: 整租·大唐总部一号 4室4厅 东南
#   驾车: 42.1公里, 66分钟
#   公交: 计算失败
#   步行: 42.2公里, 563分钟
#
# (332/414) 正在处理: 整租·昊然风景 0室0厅 东
#   驾车: 10.3公里, 33分钟
#   公交: 27分钟
#   步行: 9.8公里, 130分钟
#
# (333/414) 正在处理: 整租·和美春天 1室0厅 南
#   驾车: 11.5公里, 35分钟
#   公交: 42分钟
#   步行: 11.3公里, 150分钟
#
# (334/414) 正在处理: 整租·南宁绿地中心 2室1厅 南
#   驾车: 10.9公里, 39分钟
#   公交: 37分钟
#   步行: 9.4公里, 126分钟
#
# (335/414) 正在处理: 整租·美泉1612 4室2厅 南/北
#   驾车: 11.0公里, 36分钟
#   公交: 52分钟
#   步行: 11.0公里, 147分钟
#
# (336/414) 正在处理: 整租·五象世茂中心 1室0厅 南
#   驾车: 13.2公里, 42分钟
#   公交: 52分钟
#   步行: 12.2公里, 163分钟
#
# (337/414) 正在处理: 整租·金康天和时代 1室1厅 南
#   驾车: 5.0公里, 18分钟
#   公交: 35分钟
#   步行: 5.0公里, 66分钟
#
# (338/414) 正在处理: 整租·振宁公寓 3室2厅 东南
#   驾车: 4.9公里, 23分钟
#   公交: 33分钟
#   步行: 4.4公里, 59分钟
#
# (339/414) 正在处理: 整租·人和莱茵鹭湖 4室2厅 南
#   驾车: 14.7公里, 36分钟
#   公交: 77分钟
#   步行: 11.2公里, 150分钟
#
# (340/414) 正在处理: 整租·展厦景湾生活区 4室2厅 南
#   驾车: 7.8公里, 31分钟
#   公交: 25分钟
#   步行: 6.4公里, 86分钟
#
# (341/414) 正在处理: 整租·光明城市 4室2厅 东南/南
#   驾车: 13.2公里, 40分钟
#   公交: 49分钟
#   步行: 11.8公里, 158分钟
#
# (342/414) 正在处理: 整租·德瑞花园 2室1厅 南/北
#   驾车: 7.8公里, 32分钟
#   公交: 24分钟
#   步行: 8.1公里, 108分钟
#
# (343/414) 正在处理: 整租·蓝山上城 1室1厅 南
#   驾车: 8.0公里, 35分钟
#   公交: 31分钟
#   步行: 7.6公里, 102分钟
#
# (344/414) 正在处理: 整租·半岛康城 3室2厅 南
#   驾车: 7.1公里, 27分钟
#   公交: 55分钟
#   步行: 6.6公里, 88分钟
#
# (345/414) 正在处理: 整租·教育路3号住宅小区 4室2厅 南/北
#   驾车: 2.7公里, 13分钟
#   公交: 24分钟
#   步行: 2.6公里, 35分钟
#
# (346/414) 正在处理: 整租·金龙理想1号 3室2厅 南
#   驾车: 11.2公里, 35分钟
#   公交: 36分钟
#   步行: 10.8公里, 144分钟
#
# (347/414) 正在处理: 整租·彰泰城B区 4室2厅 南/北
#   驾车: 11.0公里, 40分钟
#   公交: 41分钟
#   步行: 10.6公里, 141分钟
#
# (348/414) 正在处理: 整租·龙光玖珑臺 1室2厅 南
#   驾车: 16.6公里, 38分钟
#   公交: 76分钟
#   步行: 16.9公里, 225分钟
#
# (349/414) 正在处理: 整租·盛世·联邦广场 3室2厅 南
#   驾车: 1.7公里, 10分钟
#   公交: 24分钟
#   步行: 0.9公里, 12分钟
#
# (350/414) 正在处理: 整租·花畔里 3室2厅 南
#   驾车: 18.2公里, 41分钟
#   公交: 76分钟
#   步行: 17.8公里, 237分钟
#
# (351/414) 正在处理: 整租·天誉城 1室1厅 南
#   驾车: 15.6公里, 44分钟
#   公交: 50分钟
#   步行: 14.9公里, 198分钟
#
# (352/414) 正在处理: 整租·云星钱隆首府E地块 3室2厅 南
#   驾车: 9.8公里, 36分钟
#   公交: 40分钟
#   步行: 9.3公里, 124分钟
#
# (353/414) 正在处理: 整租·檀府印象檀逸 4室2厅 南
#   驾车: 15.9公里, 43分钟
#   公交: 59分钟
#   步行: 14.3公里, 191分钟
#
# (354/414) 正在处理: 整租·天誉花园3组团 4室2厅 东/南
#   驾车: 15.6公里, 44分钟
#   公交: 59分钟
#   步行: 14.6公里, 194分钟
#
# (355/414) 正在处理: 整租·庭香園 1室0厅 南
#   驾车: 6.3公里, 22分钟
#   公交: 22分钟
#   步行: 6.5公里, 86分钟
#
# (356/414) 正在处理: 整租·金源CBD现代城 3室1厅 东南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (357/414) 正在处理: 整租·盛天华府 3室1厅 东南
#   驾车: 8.9公里, 42分钟
#   公交: 31分钟
#   步行: 8.9公里, 119分钟
#
# (358/414) 正在处理: 整租·金源CBD现代城 6室2厅 东南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (359/414) 正在处理: 整租·金源CBD现代城 6室2厅 东南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (360/414) 正在处理: 整租·金源CBD现代城 6室2厅 东南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (361/414) 正在处理: 整租·金源CBD现代城 6室2厅 东南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (362/414) 正在处理: 整租·金源CBD现代城 6室2厅 东南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (363/414) 正在处理: 整租·金源CBD现代城 5室2厅 东南
#   驾车: 5.8公里, 27分钟
#   公交: 26分钟
#   步行: 5.7公里, 76分钟
#
# (364/414) 正在处理: 整租·建发和鸣 2室2厅 南/北
#   驾车: 22.0公里, 45分钟
#   公交: 105分钟
#   步行: 20.8公里, 278分钟
#
# (365/414) 正在处理: 整租·建发鼎华北大珑廷 1室1厅 东南
#   驾车: 6.8公里, 27分钟
#   公交: 39分钟
#   步行: 5.1公里, 67分钟
#
# (366/414) 正在处理: 整租·金科城 3室2厅 东南
#   驾车: 17.8公里, 45分钟
#   公交: 67分钟
#   步行: 16.8公里, 224分钟
#
# (367/414) 正在处理: 整租·盛天东郡 2室2厅 南
#   驾车: 13.5公里, 35分钟
#   公交: 42分钟
#   步行: 9.5公里, 127分钟
#
# (368/414) 正在处理: 整租·城市花园 2室2厅 错层 东南
#   驾车: 6.2公里, 29分钟
#   公交: 27分钟
#   步行: 6.1公里, 81分钟
#
# (369/414) 正在处理: 整租·万达广场 1室1厅 南
#   驾车: 4.2公里, 20分钟
#   公交: 13分钟
#   步行: 4.2公里, 56分钟
#
# (370/414) 正在处理: 整租·嘉士摩根国际 3室2厅 南
#   驾车: 2.0公里, 12分钟
#   公交: 12分钟
#   步行: 1.3公里, 17分钟
#
# (371/414) 正在处理: 整租·荣和·千千树 4室2厅 南
#   驾车: 12.4公里, 33分钟
#   公交: 48分钟
#   步行: 8.7公里, 116分钟
#
# (372/414) 正在处理: 整租·凤岭名园 1室1厅 东
#   驾车: 14.6公里, 37分钟
#   公交: 50分钟
#   步行: 11.0公里, 147分钟
#
# (373/414) 正在处理: 整租·万科第五园 3室2厅 南
#   驾车: 18.7公里, 40分钟
#   公交: 64分钟
#   步行: 12.0公里, 160分钟
#
# (374/414) 正在处理: 整租·华润二十四城 3室2厅 南
#   驾车: 15.3公里, 42分钟
#   公交: 45分钟
#   步行: 14.4公里, 192分钟
#
# (375/414) 正在处理: 整租·荣和·千千树 4室2厅 南/北
#   驾车: 12.4公里, 33分钟
#   公交: 48分钟
#   步行: 8.7公里, 116分钟
#
# (376/414) 正在处理: 整租·绿地 · 国际花都 3室2厅 东南/南
#   驾车: 13.2公里, 40分钟
#   公交: 49分钟
#   步行: 11.8公里, 158分钟
#
# (377/414) 正在处理: 整租·龙光玖誉湖澜湖 3室2厅 南
#   驾车: 14.4公里, 42分钟
#   公交: 55分钟
#   步行: 14.1公里, 188分钟
#
# (378/414) 正在处理: 整租·花畔里 3室1厅 南
#   驾车: 18.2公里, 41分钟
#   公交: 76分钟
#   步行: 17.8公里, 237分钟
#
# (379/414) 正在处理: 整租·五洲国际 4室2厅 北
#   驾车: 8.7公里, 41分钟
#   公交: 33分钟
#   步行: 8.8公里, 118分钟
#
# (380/414) 正在处理: 整租·荣和大地二组团 4室2厅 南/北
#   驾车: 10.8公里, 33分钟
#   公交: 48分钟
#   步行: 9.5公里, 127分钟
#
# (381/414) 正在处理: 整租·天誉城 1室1厅 复式 南
#   驾车: 15.6公里, 44分钟
#   公交: 50分钟
#   步行: 14.9公里, 198分钟
#
# (382/414) 正在处理: 整租·保利领秀前城领秀府 4室2厅 南/北
#   驾车: 14.7公里, 43分钟
#   公交: 57分钟
#   步行: 13.0公里, 173分钟
#
# (383/414) 正在处理: 整租·龙光玖誉城翰城 3室2厅 南
#   驾车: 6.4公里, 24分钟
#   公交: 28分钟
#   步行: 6.2公里, 83分钟
#
# (384/414) 正在处理: 整租·凤岭在水一方 3室2厅 南
#   驾车: 11.5公里, 36分钟
#   公交: 48分钟
#   步行: 9.3公里, 124分钟
#
# (385/414) 正在处理: 整租·丽景豪庭 3室2厅 南
#   驾车: 6.4公里, 24分钟
#   公交: 35分钟
#   步行: 6.5公里, 86分钟
#
# (386/414) 正在处理: 整租·绿地中央广场二期 4室2厅 东南
#   驾车: 7.7公里, 29分钟
#   公交: 53分钟
#   步行: 6.2公里, 82分钟
#
# (387/414) 正在处理: 整租·世茂茂御府 3室2厅 南
#   驾车: 18.6公里, 53分钟
#   公交: 82分钟
#   步行: 18.2公里, 242分钟
#
# (388/414) 正在处理: 整租·碧桂园天玺湾 3室2厅 南
#   驾车: 13.3公里, 39分钟
#   公交: 52分钟
#   步行: 12.0公里, 160分钟
#
# (389/414) 正在处理: 整租·莱茵湖畔 2室2厅 北
#   驾车: 5.2公里, 21分钟
#   公交: 36分钟
#   步行: 5.0公里, 66分钟
#
# (390/414) 正在处理: 整租·建发五象印月 3室2厅 南/北
#   驾车: 14.4公里, 41分钟
#   公交: 52分钟
#   步行: 12.2公里, 162分钟
#
# (391/414) 正在处理: 整租·城市杰座 1室1厅 东南
#   驾车: 5.4公里, 25分钟
#   公交: 26分钟
#   步行: 5.4公里, 72分钟
#
# (392/414) 正在处理: 整租·云星钱隆天下北区 3室2厅 南
#   驾车: 5.9公里, 22分钟
#   公交: 31分钟
#   步行: 5.8公里, 77分钟
#
# (393/414) 正在处理: 整租·万达广场 1室1厅 复式 西
#   驾车: 4.2公里, 20分钟
#   公交: 13分钟
#   步行: 4.2公里, 56分钟
#
# (394/414) 正在处理: 整租·利海亚洲国际 1室0厅 南
#   驾车: 8.7公里, 41分钟
#   公交: 31分钟
#   步行: 8.6公里, 114分钟
#
# (395/414) 正在处理: 整租·建发央玺 3室2厅 南/北
#   驾车: 14.4公里, 41分钟
#   公交: 48分钟
#   步行: 12.9公里, 172分钟
#
# (396/414) 正在处理: 整租·万科第五园 5室2厅 南/北
#   驾车: 18.7公里, 40分钟
#   公交: 64分钟
#   步行: 12.0公里, 160分钟
#
# (397/414) 正在处理: 整租·和润园 5室2厅 南
#   驾车: 10.9公里, 40分钟
#   公交: 42分钟
#   步行: 9.8公里, 130分钟
#
# (398/414) 正在处理: 整租·中南紫云集（北区） 3室1厅 南
#   驾车: 14.0公里, 40分钟
#   公交: 44分钟
#   步行: 13.1公里, 175分钟
#
# (399/414) 正在处理: 整租·龙光世纪中心 3室1厅 南
#   驾车: 8.7公里, 41分钟
#   公交: 27分钟
#   步行: 8.7公里, 116分钟
#
# (400/414) 正在处理: 整租·怡景苑 2室2厅 南
#   驾车: 14.4公里, 45分钟
#   公交: 59分钟
#   步行: 13.9公里, 185分钟
#
# (401/414) 正在处理: 整租·秀山花园 3室2厅 东
#   驾车: 6.1公里, 21分钟
#   公交: 34分钟
#   步行: 6.2公里, 82分钟
#
# (402/414) 正在处理: 整租·天池山小区 3室2厅 南
#   驾车: 16.0公里, 47分钟
#   公交: 75分钟
#   步行: 15.7公里, 209分钟
#
# (403/414) 正在处理: 整租·联盟新城 6室2厅 北
#   驾车: 9.9公里, 38分钟
#   公交: 40分钟
#   步行: 9.0公里, 120分钟
#
# (404/414) 正在处理: 整租·莱茵湖畔 1室1厅 南
#   驾车: 5.2公里, 21分钟
#   公交: 36分钟
#   步行: 5.0公里, 66分钟
#
# (405/414) 正在处理: 整租·阳光城半山湾 5室2厅 南
#   驾车: 21.5公里, 49分钟
#   公交: 70分钟
#   步行: 20.0公里, 267分钟
#
# (406/414) 正在处理: 整租·云创谷 1室1厅 北
#   驾车: 13.3公里, 40分钟
#   公交: 45分钟
#   步行: 12.8公里, 171分钟
#
# (407/414) 正在处理: 整租·阳光城光明湖畔苑 3室2厅 东南/南
#   驾车: 13.2公里, 40分钟
#   公交: 60分钟
#   步行: 12.8公里, 170分钟
#
# (408/414) 正在处理: 整租·联盟新城 4室2厅 南/北
#   驾车: 9.9公里, 37分钟
#   公交: 40分钟
#   步行: 9.0公里, 120分钟
#
# (409/414) 正在处理: 整租·嘉州华都 3室2厅 南
#   驾车: 4.6公里, 19分钟
#   公交: 17分钟
#   步行: 4.2公里, 56分钟
#
# (410/414) 正在处理: 整租·彰泰城B区 1室1厅 南
#   驾车: 11.0公里, 39分钟
#   公交: 41分钟
#   步行: 10.6公里, 141分钟
#
# (411/414) 正在处理: 整租·万科城 1室1厅 南
#   驾车: 12.1公里, 33分钟
#   公交: 43分钟
#   步行: 7.5公里, 100分钟
#
# (412/414) 正在处理: 整租·云星时代广场 1室1厅 北
#   驾车: 11.3公里, 38分钟
#   公交: 44分钟
#   步行: 10.0公里, 134分钟
#
# (413/414) 正在处理: 整租·云创谷 2室2厅 西
#   驾车: 13.3公里, 40分钟
#   公交: 45分钟
#   步行: 12.8公里, 171分钟
#
# (414/414) 正在处理: 整租·天誉城 1室1厅 复式 南
#   驾车: 15.6公里, 43分钟
#   公交: 50分钟
#   步行: 14.9公里, 198分钟
#
# --- 处理完成！---
# 已将包含多种出行方式的结果保存到新文件: 'E:\xiangmu\zufang\mode.csv'
#
# 最终数据预览:
#                              标题  价格(元/月)  驾车时间  公交时间   步行时间
# 0                整租·骋望珺玺 3室2厅 南     1800  21分钟  50分钟  112分钟
# 1              整租·中海哈罗学府 3室2厅 南     1800  44分钟  76分钟  258分钟
# 2  整租·广西壮族自治区疾病预防控制中心宿舍区 4室2厅 南     2200  12分钟  34分钟   40分钟
# 3                 整租·龙滩苑 3室2厅 南     4500  33分钟  24分钟  102分钟
# 4               整租·君华•锦云 4室2厅 北     2500  47分钟  67分钟  241分钟

# %%
import pandas as pd
import requests
import time
import folium
from folium.plugins import FeatureGroupSubGroup, MarkerCluster 

GAODE_API_KEY = "你的api" 
COMPANY_ADDRESS = "公司地址"
WEIGHTS = {'price': 0.4, 'commute': 0.4, 'area': 0.2}
INPUT_CSV = '读取的数据'
OUTPUT_CSV_SCORED = '保存的数据' 
OUTPUT_MAP_HTML = '保存的地图'



def get_coordinates_final(area_string, api_key):

    parts = area_string.split(' - ')
    keyword = parts[-1] 
    

    lat, lon = search_poi_by_keyword(keyword, api_key)
    if lat:
        return lat, lon


    lat, lon = get_single_coordinate(f"南宁市{keyword}", api_key)
    if lat:
        return lat, lon


    full_address = f"你所爬取的城市{area_string.replace(' - ', '')}"
    lat, lon = get_single_coordinate(full_address, api_key)
    if not lat:
        print(f"    -> 所有策略均失败: {area_string}")

    return lat, lon

def search_poi_by_keyword(keyword, api_key):
    url = "https://restapi.amap.com/v3/place/text"
    params = {
        'key': api_key,
        'keywords': keyword,
        'city': '你所爬取的城市',
        'citylimit': True, 
        'types': '120302' 
    try:
        response = requests.get(url, params=params, timeout=10)
        data = response.json()
        if data['status'] == '1' and data['pois']:
            location = data['pois'][0]['location'] 
            lon, lat = map(float, location.split(','))
            return lat, lon
    except Exception:
        pass
    return None, None

def get_single_coordinate(address, api_key):
    geocode_url = "https://restapi.amap.com/v3/geocode/geo"
    params = {'key': api_key, 'address': address, 'city': '你所爬取的城市'}
    try:
        response = requests.get(geocode_url, params=params, timeout=10)
        data = response.json()
        if data['status'] == '1' and data['geocodes']:
            location = data['geocodes'][0]['location']
            lon, lat = map(float, location.split(','))
            return lat, lon
    except Exception:
        pass
    return None, None

def main():
    if GAODE_API_KEY == "在这里粘贴你从高德开放平台获取的Key":
        print("错误：请先在代码中配置你的高德API Key！")
        return

    df = pd.read_csv(INPUT_CSV)
    print("开始数据清洗和特征工程...")
    df['价格(元/月)'] = pd.to_numeric(df['价格(元/月)'], errors='coerce')
    df['面积(㎡)'] = pd.to_numeric(df['面积(㎡)'], errors='coerce')
    df['通勤时间(分钟)'] = pd.to_numeric(df['公交时间'].str.extract(r'([\d\.]+)')[0], errors='coerce')
    df.dropna(subset=['价格(元/月)', '面积(㎡)', '通勤时间(分钟)'], inplace=True)
    print(f"清洗后剩余 {len(df)} 条有效房源。")
    print("开始数据标准化...")
    df['价格得分'] = (df['价格(元/月)'].max() - df['价格(元/月)']) / (df['价格(元/月)'].max() - df['价格(元/月)'].min())
    df['通勤得分'] = (df['通勤时间(分钟)'].max() - df['通勤时间(分钟)']) / (df['通勤时间(分钟)'].max() - df['通勤时间(分钟)'].min())
    df['面积得分'] = (df['面积(㎡)'] - df['面积(㎡)'].min()) / (df['面积(㎡)'].max() - df['面积(㎡)'].min())
    print("计算性价比得分...")
    df['性价比得分'] = ((df['价格得分'] * WEIGHTS['price'] + df['通勤得分'] * WEIGHTS['commute'] + df['面积得分'] * WEIGHTS['area'])* 100).round(1)

    print("正在获取房源和公司地理坐标 (已采用最终优化策略)...")
    company_lat, company_lon = get_single_coordinate(COMPANY_ADDRESS, GAODE_API_KEY)
    if not company_lat:
        print("致命错误：无法获取公司坐标，程序终止。")
        return

    coords = [get_coordinates_final(row['区域'], GAODE_API_KEY) for index, row in df.iterrows()]
    coord_df = pd.DataFrame(coords, columns=['纬度', '经度'], index=df.index)
    df = pd.concat([df, coord_df], axis=1)

    original_count = len(df)
    df.dropna(subset=['纬度', '经度'], inplace=True)
    print(f"成功获取 {len(df)} / {original_count} 条房源的地理坐标。")
    
    df.to_csv(OUTPUT_CSV_SCORED, index=False, encoding='utf-8-sig')
    print(f"\n成功！已将包含性价比得分和坐标的最终数据保存到:\n{OUTPUT_CSV_SCORED}")

    print("正在生成带“蜘蛛化”功能的交互式地图...")
    m = folium.Map(location=[company_lat, company_lon], zoom_start=12)
    folium.Marker(location=[company_lat, company_lon], popup=f"<strong>公司地址</strong>", icon=folium.Icon(color='red', icon='building', prefix='fa')).add_to(m)


    marker_cluster = MarkerCluster(name='房源聚合').add_to(m)
    

    spider_group = FeatureGroupSubGroup(marker_cluster, '所有房源')
    m.add_child(spider_group)

    for idx, row in df.iterrows():
        score = row['性价比得分']
        if score > 80: color = 'green'
        elif score > 60: color = 'blue'
        elif score > 40: color = 'orange'
        else: color = 'gray'

        popup_html = f"<b>{row['标题']}</b><hr style='margin: 5px 0;'>性价比得分: <b><font color='{color}'>{score}</font></b><br>价格: {row['价格(元/月)']} 元/月<br>..."
        

        folium.CircleMarker(
            location=[row['纬度'], row['经度']],
            radius=5, color=color, fill=True, fill_color=color,
            popup=folium.Popup(popup_html, max_width=300)
        ).add_to(spider_group)
        
    m.save(OUTPUT_MAP_HTML)
    print(f"成功！已将交互式地图保存到:\n{OUTPUT_MAP_HTML}")


if __name__ == '__main__':
    main()
# Out:
# 开始数据清洗和特征工程...
# 清洗后剩余 413 条有效房源。
# 开始数据标准化...
# 计算性价比得分...
# 正在获取房源和公司地理坐标 (已采用最终优化策略)...
# 成功获取 413 / 413 条房源的地理坐标。
#
# 成功！已将包含性价比得分和坐标的最终数据保存到:
# E:\xiangmu\zufang\for_tableau.csv
# 正在生成带“蜘蛛化”功能的交互式地图...
# 成功！已将交互式地图保存到:
# E:\xiangmu\zufang\rent_map.html
